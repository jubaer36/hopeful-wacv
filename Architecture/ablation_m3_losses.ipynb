# %% [markdown]
# # HyFIN-Net — M3 Ablation: Loss Design
#
# Implements the M3 grid from `m2_m3_m4_m6_implementation_plan.md`:
# label-smoothing × class-balance interaction grid (L0–L3, judged on mF1 +
# minority-class F1), CBFC γ sweep (L4), BCL replacing CBFC (L5, dialogue and
# global scope), EACL anchors (L6, judged on hap↔exc and ang↔fru pair F1),
# and the 3-seed winner stack (L7).

# %%
import subprocess, sys, importlib
def _try(mod):
    try:
        importlib.import_module(mod); return True
    except Exception:
        return False
if not _try('torch_scatter') or not _try('torch_sparse'):
    import torch as _t
    tv = _t.__version__.split('+')[0]
    cu = _t.version.cuda.replace('.', '') if _t.version.cuda else 'cpu'
    url = f'https://data.pyg.org/whl/torch-{tv}+cu{cu}.html'
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '--no-index',
                    'torch_scatter', 'torch_sparse', '-f', url], check=False)
    if not _try('torch_geometric'):
        subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'torch_geometric'], check=False)
import torch, torch_geometric
print('torch', torch.__version__, '| cuda', torch.version.cuda, '| pyg', torch_geometric.__version__)
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU only')
import os
IS_KAGGLE = os.path.exists('/kaggle/working')
print('Platform: Kaggle' if IS_KAGGLE else 'Platform: local')
# Out:
# torch 2.11.0+cu128 | cuda 12.8 | pyg 2.7.0
# GPU: NVIDIA GeForce RTX 3060
# Platform: local

# %%
import os, pickle, math, random, time, copy, json
from pathlib import Path
from itertools import permutations
from dataclasses import dataclass, field
from typing import Optional
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch_geometric.nn import GraphConv, TransformerConv
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import softmax as pyg_softmax, degree
from torch_scatter import scatter_add
from sklearn.metrics import f1_score, accuracy_score, classification_report

SEED = 2024
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)

# ── Ablation-study settings ───────────────────────────────────────────────────
ABLATION_EPOCHS = 30          # use 60 for full-fidelity; 30 for fast sweep
ABLATION_SEED   = 42
# Out:
# device = cuda

# %%
_LOCAL_DATA_ROOT = os.environ.get(
    'GRAPHSMILE_DATA',
    str(Path('/mnt/Work/ML/Thesis/WACV/data/GraphSmile_PreProcessed')))
_LOCAL_SAVE_DIR = os.environ.get('HYFIN_SAVE_DIR', './outputs')

class Cfg:
    dataset      = 'iemocap'
    data_root    = ('/kaggle/input/datasets/gilbertstrange/graphsmile-preprocessed/GraphSmile_PreProcessed'
                    if IS_KAGGLE else _LOCAL_DATA_ROOT)
    save_dir     = '/kaggle/working' if IS_KAGGLE else _LOCAL_SAVE_DIR
    @property
    def meld_path(self):    return f'{self.data_root}/meld_multi_features.pkl'
    @property
    def iemocap_path(self): return f'{self.data_root}/iemocap_multi_features.pkl'
    batch_size_d = {'iemocap': 16, 'meld': 32}
    epochs       = 60      # full training epochs (not used for ablation)
    lr           = 4e-4
    weight_decay = 1e-4
    grad_clip    = 1.0
    warmup_epochs = 1
    label_smoothing = 0.1
    hidden       = 256
    n_speakers   = {'iemocap': 2, 'meld': 9}
    n_classes    = {'iemocap': 6, 'meld': 7}
    igm_branches = {
        'iemocap': [(5, 3), (3, 2)],
        'meld':    [(7, 4), (5, 3)],
    }
    igm_layers   = 2
    igm_heads    = 4
    hm_layers    = {'iemocap': 2, 'meld': 4}
    mf_layers    = {'iemocap': 4, 'meld': 3}
    ca_heads     = 4
    dropout      = {'iemocap': 0.5, 'meld': 0.5}
    beta_cb      = 0.999
    cbfc_mu      = 0.1
    cbfc_gamma   = 2.0
    cbfc_temp    = 0.5
    dualcl_lam   = 0.0
    dualcl_tau   = 0.5
    dualcl_drop  = 0.1
    max_hm_nodes = 50_000
    max_hm_edges = 50_000
    val_frac     = 0.1
    log_every    = 999999   # suppress step-level logs during ablation sweep
    @property
    def batch_size(self): return self.batch_size_d[self.dataset]

cfg = Cfg()
os.makedirs(cfg.save_dir, exist_ok=True)
print(f'data_root: {cfg.data_root}')
print(f'save_dir : {cfg.save_dir}')
# Out:
# data_root: /mnt/Work/ML/Thesis/WACV/data/GraphSmile_PreProcessed
# save_dir : ./outputs

# %%
ABL_OUT  = Path(cfg.save_dir) / 'ablation_m3'
PLOT_DIR = ABL_OUT / 'plots'
CKPT_DIR = ABL_OUT / 'checkpoints'
RESULTS_FILE = ABL_OUT / 'ablation_m3_results.json'

for d in [ABL_OUT, PLOT_DIR, CKPT_DIR]:
    d.mkdir(parents=True, exist_ok=True)

def _load_results():
    if RESULTS_FILE.exists():
        with open(RESULTS_FILE) as f:
            return json.load(f)
    return {}

def _save_results(results):
    with open(RESULTS_FILE, 'w') as f:
        json.dump(results, f, indent=2)

print('Output dir:', ABL_OUT)
# Out:
# Output dir: outputs/ablation_m3

# %%
def _load_pickle(path):
    with open(path, 'rb') as f:
        try:
            return pickle.load(f, encoding='latin1')
        except TypeError:
            f.seek(0); return pickle.load(f)

def parse_graphsmile_pickle(path, dataset):
    obj = _load_pickle(path)
    assert isinstance(obj, (tuple, list)), f'unexpected pickle type {type(obj)}'
    n = len(obj)
    if n == 9:
        (videoIDs, videoSpeakers, videoLabels,
         videoText, videoAudio, videoVisual, videoSentence,
         trainVid, testVid) = obj
        text_dict = videoText
    elif n in (12,):
        (videoIDs, videoSpeakers, videoLabels,
         vT0, vT1, vT2, vT3,
         videoAudio, videoVisual, videoSentence,
         trainVid, testVid) = obj
        text_dict = {vid: (np.asarray(vT0[vid], dtype=np.float32)
                          + np.asarray(vT1[vid], dtype=np.float32)
                          + np.asarray(vT2[vid], dtype=np.float32)
                          + np.asarray(vT3[vid], dtype=np.float32)) / 4.0
                     for vid in vT0.keys()}
    elif n in (13, 14):
        (videoIDs, videoSpeakers, videoLabels, videoSentiments,
         vT0, vT1, vT2, vT3,
         videoAudio, videoVisual, videoSentence,
         trainVid, testVid, *rest) = obj
        text_dict = {vid: (np.asarray(vT0[vid], dtype=np.float32)
                          + np.asarray(vT1[vid], dtype=np.float32)
                          + np.asarray(vT2[vid], dtype=np.float32)
                          + np.asarray(vT3[vid], dtype=np.float32)) / 4.0
                     for vid in vT0.keys()}
    else:
        raise ValueError(f'unsupported pickle layout: {n} fields')

    sample_vid = next(iter(text_dict))
    Dt = int(np.asarray(text_dict[sample_vid]).shape[-1])
    Da = int(np.asarray(videoAudio[sample_vid]).shape[-1])
    Dv = int(np.asarray(videoVisual[sample_vid]).shape[-1])
    print(f'  layout={n} fields  dims t/a/v = {Dt}/{Da}/{Dv}  train={len(trainVid)}, test={len(testVid)}')
    return dict(text=text_dict, audio=videoAudio, visual=videoVisual,
                labels=videoLabels, speakers=videoSpeakers, sentences=videoSentence,
                trainVid=list(trainVid), testVid=list(testVid))

def _speaker_to_idx(spk, dataset):
    if dataset == 'iemocap':
        out = []
        for s in spk:
            if isinstance(s, (str, bytes)):
                ss = s.decode() if isinstance(s, bytes) else s
                out.append({'M': 0, 'F': 1}.get(ss, 0))
            else:
                out.append(int(s))
        return out
    arr = np.asarray(spk)
    if arr.ndim == 2:
        return arr.argmax(-1).tolist()
    return arr.astype(int).tolist()

class MERCDataset(Dataset):
    def __init__(self, raw, vids, dataset):
        self.raw = raw; self.vids = vids; self.dataset = dataset
    def __len__(self): return len(self.vids)
    def __getitem__(self, idx):
        vid = self.vids[idx]
        t = np.asarray(self.raw['text'][vid],   dtype=np.float32)
        a = np.asarray(self.raw['audio'][vid],  dtype=np.float32)
        v = np.asarray(self.raw['visual'][vid], dtype=np.float32)
        y = np.asarray(self.raw['labels'][vid], dtype=np.int64)
        spk = _speaker_to_idx(self.raw['speakers'][vid], self.dataset)
        return {
            'text': torch.from_numpy(t), 'audio': torch.from_numpy(a),
            'visual': torch.from_numpy(v), 'label': torch.from_numpy(y),
            'speaker': torch.tensor(spk, dtype=torch.long),
            'length': int(t.shape[0]),
        }

def pad_collate(batch):
    B = len(batch)
    L = max(s['length'] for s in batch)
    Dt = batch[0]['text'].shape[-1]
    Da = batch[0]['audio'].shape[-1]
    Dv = batch[0]['visual'].shape[-1]
    text   = torch.zeros(B, L, Dt)
    audio  = torch.zeros(B, L, Da)
    visual = torch.zeros(B, L, Dv)
    spk    = torch.zeros(B, L, dtype=torch.long)
    lens   = torch.zeros(B, dtype=torch.long)
    labels = []
    for i, s in enumerate(batch):
        n = s['length']
        text[i, :n]   = s['text']
        audio[i, :n]  = s['audio']
        visual[i, :n] = s['visual']
        spk[i, :n]    = s['speaker']
        lens[i]       = n
        labels.append(s['label'])
    return {'text': text, 'audio': audio, 'visual': visual,
            'speaker': spk, 'lengths': lens, 'labels': torch.cat(labels)}

# Load data
path = cfg.meld_path if cfg.dataset == 'meld' else cfg.iemocap_path
print(f'loading {path}')
raw = parse_graphsmile_pickle(path, dataset=cfg.dataset)
print('train vids:', len(raw['trainVid']), 'test vids:', len(raw['testVid']))

probe_dims = []
for vid in list(raw['trainVid'])[:5]:
    t = np.asarray(raw['text'][vid]); a = np.asarray(raw['audio'][vid]); v = np.asarray(raw['visual'][vid])
    probe_dims.append((t.shape[-1], a.shape[-1], v.shape[-1]))
assert len(set(probe_dims)) == 1
D_T, D_A, D_V = probe_dims[0]
print(f'feature dims t/a/v = {D_T}/{D_A}/{D_V}')

# Split
train_all = list(raw['trainVid'])
rng = random.Random(SEED); rng.shuffle(train_all)
n_val = max(1, int(len(train_all) * cfg.val_frac))
val_vids   = train_all[:n_val]
train_vids = train_all[n_val:]
test_vids  = list(raw['testVid'])

num_workers = 2 if IS_KAGGLE else min(4, os.cpu_count() or 1)
train_set  = MERCDataset(raw, train_vids, cfg.dataset)
val_set    = MERCDataset(raw, val_vids,   cfg.dataset)
test_set   = MERCDataset(raw, test_vids,  cfg.dataset)
train_loader = DataLoader(train_set, batch_size=cfg.batch_size, shuffle=True,
                          collate_fn=pad_collate, num_workers=num_workers, pin_memory=IS_KAGGLE)
val_loader   = DataLoader(val_set,   batch_size=cfg.batch_size, shuffle=False,
                          collate_fn=pad_collate, num_workers=num_workers, pin_memory=IS_KAGGLE)
test_loader  = DataLoader(test_set,  batch_size=cfg.batch_size, shuffle=False,
                          collate_fn=pad_collate, num_workers=num_workers, pin_memory=IS_KAGGLE)
print(f'split: train={len(train_set)}  val={len(val_set)}  test={len(test_set)}')

class_counts = np.zeros(cfg.n_classes[cfg.dataset], dtype=np.int64)
for vid in train_vids:
    for y in raw['labels'][vid]:
        class_counts[int(y)] += 1
print('train class counts:', class_counts.tolist())
# Out:
# loading /mnt/Work/ML/Thesis/WACV/data/GraphSmile_PreProcessed/iemocap_multi_features.pkl
#   layout=12 fields  dims t/a/v = 1024/1582/342  train=120, test=31
# train vids: 120 test vids: 31
# feature dims t/a/v = 1024/1582/342
# split: train=108  val=12  test=31
# train class counts: [474, 763, 1200, 814, 711, 1267]

# %% [markdown]
# ## Original Model Classes (verbatim from arch21.ipynb)

# %%
# ── Block A: Unimodal Encoder ─────────────────────────────────────────────────

class InputLN(nn.Module):
    """Masked per-dialogue LayerNorm over each dialogue's TRUE (unpadded) (n, D) block."""
    def __init__(self, eps=1e-5):
        super().__init__()
        self.eps = eps
    def forward(self, x, lengths):
        B, L, D = x.shape
        if L == 0:
            return x
        valid = (torch.arange(L, device=x.device)[None, :] < lengths[:, None]).unsqueeze(-1)
        vf = valid.to(x.dtype)
        cnt = (vf.sum(dim=(1, 2), keepdim=True) * D).clamp(min=1.0)
        mean = (x * vf).sum(dim=(1, 2), keepdim=True) / cnt
        var = (((x - mean) ** 2) * vf).sum(dim=(1, 2), keepdim=True) / cnt
        out = (x - mean) / torch.sqrt(var + self.eps)
        return out * vf

class PositionalEncoding(nn.Module):
    def __init__(self, d, max_len=200):
        super().__init__()
        pe = torch.zeros(max_len, d)
        pos = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, d, 2).float() * (-math.log(10000.0) / d))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.register_buffer('pe', pe.unsqueeze(0))
    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class UnimodalEncoder(nn.Module):
    def __init__(self, d_t, d_a, d_v, d_h, n_speakers, dropout=0.5):
        super().__init__()
        self.in_ln_t = InputLN()
        self.in_ln_a = InputLN()
        self.in_ln_v = InputLN()
        self.t_proj = nn.Linear(d_t, d_h)
        self.pe     = PositionalEncoding(d_h)
        self.t_enc  = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=d_h, nhead=4, dim_feedforward=d_h,
                                       dropout=dropout, activation='gelu', batch_first=True),
            num_layers=1)
        self.a_proj = nn.Sequential(nn.Linear(d_a, d_h), nn.ReLU(), nn.Dropout(dropout))
        self.v_proj = nn.Sequential(nn.Linear(d_v, d_h), nn.ReLU(), nn.Dropout(dropout))
        self.spk    = nn.Embedding(n_speakers, d_h)
    def forward(self, text, audio, visual, spk, lengths):
        B, L, _ = text.shape
        mask = torch.arange(L, device=text.device)[None] >= lengths[:, None]
        text   = self.in_ln_t(text,   lengths)
        audio  = self.in_ln_a(audio,  lengths)
        visual = self.in_ln_v(visual, lengths)
        ht = self.t_enc(self.pe(self.t_proj(text)), src_key_padding_mask=mask)
        ha = self.a_proj(audio)
        hv = self.v_proj(visual)
        s = self.spk(spk)
        return ht + s, ha + s, hv + s, mask

# ── Graph helpers ─────────────────────────────────────────────────────────────

def flatten_batch(ht, ha, hv, lengths):
    feats, offsets = [], []; cur = 0
    for b, n in enumerate(lengths.tolist()):
        feats.append(torch.cat([ht[b, :n], ha[b, :n], hv[b, :n]], dim=0))
        offsets.append(cur); cur += 3 * n
    return torch.cat(feats, dim=0), offsets

def unflatten_batch(flat, lengths, offsets):
    B = len(lengths); L = int(lengths.max().item()); H = flat.shape[-1]
    ht = flat.new_zeros(B, L, H); ha = flat.new_zeros(B, L, H); hv = flat.new_zeros(B, L, H)
    for b, n in enumerate(lengths.tolist()):
        o = offsets[b]
        ht[b, :n] = flat[o:o+n]; ha[b, :n] = flat[o+n:o+2*n]; hv[b, :n] = flat[o+2*n:o+3*n]
    return ht, ha, hv

def angular_weight(x, edge_index):
    src, dst = edge_index
    xs = F.normalize(x[src], dim=-1); xd = F.normalize(x[dst], dim=-1)
    cos = (xs * xd).sum(-1).clamp(-1 + 1e-6, 1 - 1e-6)
    return 1.0 - torch.arccos(cos) / math.pi

# ── Block B-IGM: Inception Graph Module ──────────────────────────────────────

class ImplicitEdgeDetector(nn.Module):
    def __init__(self, d):
        super().__init__()
        self.W = nn.Linear(2 * d, 1, bias=False)
        self.act = nn.LeakyReLU(0.2)
    def extra_edges(self, feats_per_modality, n):
        if n < 2: return None, None
        f = feats_per_modality
        fi = f.unsqueeze(1).expand(n, n, -1)
        fj = f.unsqueeze(0).expand(n, n, -1)
        s = self.act(self.W(torch.cat([fi, fj], dim=-1)).squeeze(-1))
        causal = torch.tril(torch.ones(n, n, device=f.device, dtype=torch.bool))
        s = s.masked_fill(~causal, -1e9)
        a = F.softmax(s, dim=-1)
        keep = (a > (1.0 / n)) & causal
        idx = keep.nonzero(as_tuple=False)
        if idx.numel() == 0: return None, None
        return idx[:, 0], idx[:, 1]

def build_igm_graph(lengths, offsets, ht, ha, hv, p_window, f_window, implicit=None, device='cpu'):
    src, dst = [], []; feats_for_implicit = (ht, ha, hv)
    for b, n in enumerate(lengths.tolist()):
        o = offsets[b]
        t0, a0, v0 = o, o + n, o + 2 * n
        idx_t = torch.arange(n, device=device) + t0
        idx_a = torch.arange(n, device=device) + a0
        idx_v = torch.arange(n, device=device) + v0
        for x, y in [(idx_t, idx_a), (idx_t, idx_v), (idx_a, idx_v)]:
            src.append(x); dst.append(y); src.append(y); dst.append(x)
        for idx in (idx_t, idx_a, idx_v):
            i_grid = torch.arange(n, device=device)
            for shift in range(1, p_window + 1):
                m = i_grid >= shift
                if m.any():
                    src.append(idx[m]); dst.append(idx[m] - shift)
                    src.append(idx[m] - shift); dst.append(idx[m])
            for shift in range(1, f_window + 1):
                m = (i_grid + shift) < n
                if m.any():
                    src.append(idx[m]); dst.append(idx[m] + shift)
                    src.append(idx[m] + shift); dst.append(idx[m])
        if implicit is not None:
            for mod_idx, base in enumerate([t0, a0, v0]):
                mod_feats = feats_for_implicit[mod_idx][b, :n]
                u, w = implicit.extra_edges(mod_feats, n)
                if u is not None:
                    u = u + base; w = w + base
                    src.append(u); dst.append(w); src.append(w); dst.append(u)
    if len(src) == 0:
        return torch.zeros(2, 0, dtype=torch.long, device=device)
    src = torch.cat(src, dim=0); dst = torch.cat(dst, dim=0)
    return torch.stack([src, dst], dim=0)

class IGMBranch(nn.Module):
    def __init__(self, d, n_layers, heads=4, dropout=0.1):
        super().__init__()
        assert d % heads == 0
        d_head = d // heads
        self.convs = nn.ModuleList([
            TransformerConv(in_channels=d, out_channels=d_head, heads=heads,
                            concat=True, beta=True, dropout=dropout, edge_dim=1)
            for _ in range(n_layers)])
        self.norms = nn.ModuleList([nn.LayerNorm(d) for _ in range(n_layers)])
    def forward(self, x, edge_index, edge_weight=None):
        edge_attr = None if edge_weight is None else edge_weight.unsqueeze(-1)
        h = x
        for conv, ln in zip(self.convs, self.norms):
            h = ln(F.relu(conv(h, edge_index, edge_attr)) + h)
        return h

class InceptionGraphModule(nn.Module):
    def __init__(self, d, windows, n_layers, heads=4, dropout=0.1):
        super().__init__()
        self.windows = windows
        self.branches = nn.ModuleList([IGMBranch(d, n_layers, heads=heads, dropout=dropout)
                                       for _ in windows])
        self.implicit = ImplicitEdgeDetector(d)
    def forward(self, flat, lengths, offsets, ht, ha, hv):
        outs = []
        for (p, f), branch in zip(self.windows, self.branches):
            edge_index = build_igm_graph(lengths, offsets, ht, ha, hv,
                                         p, f, implicit=self.implicit, device=flat.device)
            ew = angular_weight(flat, edge_index)
            outs.append(branch(flat, edge_index, ew))
        return torch.stack(outs, dim=0).mean(dim=0)

# ── Block B-HM: Hypergraph Module ────────────────────────────────────────────

class HypergraphConvM3(nn.Module):
    def __init__(self, d_in, d_out):
        super().__init__()
        self.lin = nn.Linear(d_in, d_out, bias=False)
        self.bias = nn.Parameter(torch.zeros(d_out))
    def forward(self, x, hyperedge_index, hyperedge_weight=None, ew_weight=None):
        N = x.size(0)
        if hyperedge_index.numel() == 0:
            return F.leaky_relu(self.lin(x) + self.bias)
        node_idx, edge_idx = hyperedge_index[0], hyperedge_index[1]
        E = int(edge_idx.max().item()) + 1
        if hyperedge_weight is None:
            hyperedge_weight = x.new_ones(E)
        D = scatter_add(hyperedge_weight[edge_idx], node_idx, dim=0, dim_size=N)
        D = 1.0 / D; D[D == float('inf')] = 0
        if ew_weight is None:
            B_ = scatter_add(x.new_ones(hyperedge_index.size(1)), edge_idx, dim=0, dim_size=E)
        else:
            B_ = scatter_add(ew_weight[node_idx], edge_idx, dim=0, dim_size=E)
        B_ = 1.0 / B_; B_[B_ == float('inf')] = 0
        h = self.lin(x)
        msg_n2e = h[node_idx] * B_[edge_idx].unsqueeze(-1)
        out_e   = scatter_add(msg_n2e, edge_idx, dim=0, dim_size=E)
        msg_e2n = out_e[edge_idx] * D[node_idx].unsqueeze(-1)
        out_n   = scatter_add(msg_e2n, node_idx, dim=0, dim_size=N)
        return F.leaky_relu(out_n + self.bias)

def build_hyperedge_index(lengths, offsets, device):
    nodes, edges = [], []; edge_count = 0
    for b, n in enumerate(lengths.tolist()):
        o = offsets[b]; t0, a0, v0 = o, o + n, o + 2 * n
        for base in (t0, a0, v0):
            for k in range(n):
                nodes.append(base + k); edges.append(edge_count)
            edge_count += 1
        for k in range(n):
            nodes.extend([t0 + k, a0 + k, v0 + k])
            edges.extend([edge_count] * 3); edge_count += 1
    if len(nodes) == 0:
        return torch.zeros(2, 0, dtype=torch.long, device=device)
    return torch.tensor([nodes, edges], dtype=torch.long, device=device)

class HyperGraphModule(nn.Module):
    def __init__(self, d, n_layers, max_nodes=50_000, max_edges=50_000):
        super().__init__()
        self.convs = nn.ModuleList([HypergraphConvM3(d, d) for _ in range(n_layers)])
        self.hyperedge_weight = nn.Parameter(torch.ones(max_edges))
        self.ew_weight        = nn.Parameter(torch.ones(max_nodes))
    def forward(self, flat, lengths, offsets):
        hi = build_hyperedge_index(lengths, offsets, flat.device)
        E = int(hi[1].max().item()) + 1; N = flat.size(0)
        w = self.hyperedge_weight[:E]; ew = self.ew_weight[:N]
        h = flat
        for conv in self.convs:
            h = conv(h, hi, w, ew)
        return h

# ── Block C: Multi-Frequency Module ──────────────────────────────────────────

class HighFreqConv(MessagePassing):
    def __init__(self, d):
        super().__init__(aggr='add')
        self.gate = nn.Linear(2 * d, 1)
    def forward(self, x, edge_index):
        return self.propagate(edge_index, size=(x.size(0), x.size(0)), x=x)
    def message(self, x_i, x_j, edge_index, size):
        row, col = edge_index
        deg_ = degree(row, size[0], dtype=x_j.dtype)
        d_inv = deg_.pow(-0.5)
        norm  = d_inv[row] * d_inv[col]
        a_g   = torch.tanh(self.gate(torch.cat([x_i, x_j], dim=1)))
        return norm.view(-1, 1) * x_j * a_g

def build_mf_edges(lengths, offsets, device):
    src, dst = [], []
    for b, n in enumerate(lengths.tolist()):
        o = offsets[b]; t0, a0, v0 = o, o + n, o + 2 * n
        for base in (t0, a0, v0):
            for pair in permutations(range(n), 2):
                src.append(base + pair[0]); dst.append(base + pair[1])
        for k in range(n):
            ids = [t0 + k, a0 + k, v0 + k]
            for x, y in permutations(ids, 2):
                src.append(x); dst.append(y)
    if len(src) == 0:
        return torch.zeros(2, 0, dtype=torch.long, device=device)
    return torch.tensor([src, dst], dtype=torch.long, device=device)

class MultiFrequencyModule(nn.Module):
    def __init__(self, d, k_layers):
        super().__init__()
        self.convs = nn.ModuleList([HighFreqConv(d) for _ in range(k_layers)])
    def forward(self, flat, lengths, offsets):
        ei = build_mf_edges(lengths, offsets, flat.device)
        h = flat
        for c in self.convs:
            h = h + c(h, ei)
        return h

# ── Block E: Cross-Modal Attention + Block F: Classifier ─────────────────────

class CrossModalAttn(nn.Module):
    def __init__(self, d_in, d_h, heads=4, dropout=0.3):
        super().__init__()
        self.proj_t = nn.Linear(d_in, d_h)
        self.proj_a = nn.Linear(d_in, d_h)
        self.proj_v = nn.Linear(d_in, d_h)
        self.va = nn.MultiheadAttention(d_h, heads, dropout=dropout, batch_first=True)
        self.aa = nn.MultiheadAttention(d_h, heads, dropout=dropout, batch_first=True)
    def forward(self, mt, ma, mv, key_padding_mask):
        mt = F.gelu(self.proj_t(mt)); ma = F.gelu(self.proj_a(ma)); mv = F.gelu(self.proj_v(mv))
        v_to_t, _ = self.va(mt, mv, mv, key_padding_mask=key_padding_mask)
        a_to_t, _ = self.aa(mt, ma, ma, key_padding_mask=key_padding_mask)
        return torch.cat([mt + v_to_t + a_to_t, ma, mv], dim=-1)

class Classifier(nn.Module):
    def __init__(self, d_in, n_classes, dropout=0.3):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(d_in, d_in // 2), nn.ReLU(), nn.Dropout(dropout),
            nn.Linear(d_in // 2, n_classes))
    def forward(self, z): return self.net(z)

# ── HyFINNet assembly ─────────────────────────────────────────────────────────

class HyFINNet(nn.Module):
    def __init__(self, cfg, d_t, d_a, d_v):
        super().__init__()
        d = cfg.hidden; ds = cfg.dataset
        self.cfg = cfg
        self.encoder = UnimodalEncoder(d_t, d_a, d_v, d, cfg.n_speakers[ds], cfg.dropout[ds])
        self.igm = InceptionGraphModule(d, cfg.igm_branches[ds], cfg.igm_layers,
                                        heads=cfg.igm_heads, dropout=cfg.dropout[ds])
        self.hm  = HyperGraphModule(d, cfg.hm_layers[ds], cfg.max_hm_nodes, cfg.max_hm_edges)
        self.mf  = MultiFrequencyModule(d, cfg.mf_layers[ds])
        d_cat = 3 * d
        self.cross = CrossModalAttn(d_in=d_cat, d_h=d, heads=cfg.ca_heads, dropout=cfg.dropout[ds])
        self.clf = Classifier(3 * d, cfg.n_classes[ds], cfg.dropout[ds])
    def _features(self, batch):
        text   = batch['text'].to(device)
        audio  = batch['audio'].to(device)
        visual = batch['visual'].to(device)
        spk    = batch['speaker'].to(device)
        lens   = batch['lengths'].to(device)
        ht, ha, hv, key_pad_mask = self.encoder(text, audio, visual, spk, lens)
        flat, offsets = flatten_batch(ht, ha, hv, lens)
        p_flat = self.igm(flat, lens, offsets, ht, ha, hv)
        q_flat = self.hm(flat, lens, offsets)
        f_flat = self.mf(flat, lens, offsets)
        m_flat = torch.cat([p_flat, q_flat, f_flat], dim=-1)
        mt, ma, mv = unflatten_batch(m_flat, lens, offsets)
        fused = self.cross(mt, ma, mv, key_padding_mask=key_pad_mask)
        return fused, key_pad_mask, lens
    def forward(self, batch, return_repr=False):
        fused, key_pad_mask, lens = self._features(batch)
        z = fused[~key_pad_mask]
        logits = self.clf(z)
        if return_repr:
            B = lens.size(0)
            dialogue_ids = torch.arange(B, device=z.device).repeat_interleave(lens)
            return logits, z, dialogue_ids
        return logits

print('Original model classes loaded.')
# Out:
# Original model classes loaded.

# %%
def effective_class_weights(class_counts, beta=0.999):
    eff = 1.0 - np.power(beta, class_counts)
    w = (1.0 - beta) / np.maximum(eff, 1e-12)
    w = w / w.sum() * len(class_counts)
    return torch.tensor(w, dtype=torch.float32)

class CBCELoss(nn.Module):
    def __init__(self, w, label_smoothing=0.0):
        super().__init__()
        self.register_buffer('w', w); self.ls = label_smoothing
    def forward(self, logits, y):
        return F.cross_entropy(logits, y, weight=self.w.to(logits.device),
                               label_smoothing=self.ls)

class CBFCLoss(nn.Module):
    def __init__(self, w, gamma=2.0, temp=0.5):
        super().__init__()
        self.register_buffer('w', w); self.gamma = gamma; self.temp = temp
    def forward(self, z, y, dialogue_ids):
        N = z.size(0)
        if N < 2: return z.new_zeros(())
        zn  = F.normalize(z, dim=-1)
        sim = (zn @ zn.t()) / self.temp
        same_dia  = dialogue_ids[:, None] == dialogue_ids[None, :]
        self_mask = torch.eye(N, dtype=torch.bool, device=z.device)
        cand = same_dia & ~self_mask
        pos  = cand & (y[:, None] == y[None, :])
        neg_inf = torch.finfo(sim.dtype).min
        logt = F.log_softmax(sim.masked_fill(~cand, neg_inf), dim=-1)
        t    = logt.exp()
        term = (1.0 - t).pow(self.gamma) * logt
        term = term.masked_fill(~pos, 0.0)
        num_pos = pos.sum(-1); valid = num_pos > 0
        if not valid.any(): return z.new_zeros(())
        per_anchor = -term.sum(-1) / num_pos.clamp(min=1)
        wj = self.w.to(z.device)[y]
        return (wj * per_anchor)[valid].sum() / valid.sum().clamp(min=1)

@torch.no_grad()
def evaluate(model, loader, loss_fns=None):
    model.eval()
    ys, ps = [], []
    total_loss, nb = 0.0, 0
    for batch in loader:
        if loss_fns is not None:
            cbce_fn, cbfc_fn, mu = loss_fns
            logits, z, dia = model(batch, return_repr=True)
            y = batch['labels'].to(device)
            l_ce = cbce_fn(logits, y)
            l_fc = cbfc_fn(z, y, dia) if mu > 0 else logits.new_zeros(())
            total_loss += (l_ce + mu * l_fc).item(); nb += 1
        else:
            logits = model(batch)
        ps.append(logits.argmax(-1).cpu().numpy())
        ys.append(batch['labels'].numpy())
    ys = np.concatenate(ys); ps = np.concatenate(ps)
    acc = accuracy_score(ys, ps)
    wf1 = f1_score(ys, ps, average='weighted')
    mf1 = f1_score(ys, ps, average='macro')
    mean_loss = (total_loss / max(1, nb)) if loss_fns is not None else None
    return acc, wf1, mf1, ys, ps, mean_loss

def make_ablation_scheduler(optim, cfg, steps_per_epoch, epochs):
    """Cosine annealing scheduler using explicit epoch count (not cfg.epochs)."""
    warmup_steps = cfg.warmup_epochs * steps_per_epoch
    total_steps  = epochs * steps_per_epoch
    def lr_lambda(step):
        if step < warmup_steps:
            return float(step + 1) / float(max(1, warmup_steps))
        progress = (step - warmup_steps) / float(max(1, total_steps - warmup_steps))
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optim, lr_lambda)

print('Losses, evaluate, scheduler loaded.')
# Out:
# Losses, evaluate, scheduler loaded.

# %% [markdown]
# ## M3 Infrastructure

# %%
from dataclasses import replace

@dataclass
class AblationCfg:
    """M3 — loss-design flags."""
    label_smoothing: float = 0.1
    cb_weights:      bool  = True
    contrastive:     str   = 'cbfc'   # 'off' | 'cbfc' | 'bcl' | 'bcl_global'
    cbfc_gamma:      float = 2.0
    contrast_mu:     float = 0.1
    eacl:            bool  = False
    eacl_lambda:     float = 0.2

print('AblationCfg (M3) defined.')
# Out:
# AblationCfg (M3) defined.

# %%
class BCLLoss(nn.Module):
    """Balanced Contrastive Loss (Zhu et al., CVPR 2022): class-averaged
    positives + class-complement denominator. Vectorized; optional
    within-dialogue scoping for comparability with CBFC."""
    def __init__(self, temp=0.5, dialogue_scoped=True):
        super().__init__()
        self.t = temp
        self.dialogue_scoped = dialogue_scoped
    def forward(self, z, y, dia=None):
        N = z.size(0)
        if N < 2:
            return z.new_zeros(())
        zn = F.normalize(z, dim=-1)
        sim = zn @ zn.t() / self.t
        eye = torch.eye(N, dtype=torch.bool, device=z.device)
        if self.dialogue_scoped and dia is not None:
            scope = (dia[:, None] == dia[None, :]) & ~eye
        else:
            scope = ~eye
        ex = torch.exp(sim) * scope.float()
        denom = z.new_zeros(N)
        for c in y.unique():
            colmask = ((y == c)[None, :] & scope).float()
            cnt = colmask.sum(1).clamp(min=1)
            denom = denom + (ex * colmask).sum(1) / cnt       # class-averaged
        pos = (y[:, None] == y[None, :]) & scope
        npos = pos.sum(1)
        num = (ex * pos.float()).sum(1) / npos.clamp(min=1)
        valid = (npos > 0) & (denom > 0)
        if not valid.any():
            return z.new_zeros(())
        return -torch.log((num[valid] / denom[valid]).clamp(min=1e-12)).mean()

class EACLLoss(nn.Module):
    """Emotion-anchored contrastive loss: pull representations to learnable
    class anchors, push anchors apart with a margin separation term."""
    def __init__(self, n_classes, d, temp=0.1, margin=0.3, lam_sep=0.1):
        super().__init__()
        self.anchors = nn.Parameter(F.normalize(torch.randn(n_classes, d), dim=-1))
        self.t, self.m, self.lam = temp, margin, lam_sep
    def forward(self, z, y):
        a = F.normalize(self.anchors, dim=-1)
        logits = F.normalize(z, dim=-1) @ a.t() / self.t
        l_pull = F.cross_entropy(logits, y)
        d_aa = a @ a.t() - 2 * torch.eye(len(a), device=a.device)
        l_sep = F.relu(self.m - (1 - d_aa)).triu(1).mean()
        return l_pull + self.lam * l_sep

print('BCLLoss / EACLLoss defined.')
# Out:
# BCLLoss / EACLLoss defined.

# %%
def build_model(ab):
    return HyFINNet(cfg, D_T, D_A, D_V)     # M3 never changes the architecture

def build_losses(ab, model):
    C = cfg.n_classes[cfg.dataset]
    if ab.cb_weights:
        w = effective_class_weights(class_counts, beta=cfg.beta_cb).to(device)
    else:
        w = torch.ones(C, device=device)
    cbce = CBCELoss(w, label_smoothing=ab.label_smoothing)
    contrast, mu = None, 0.0
    if ab.contrastive == 'cbfc':
        contrast = CBFCLoss(w, gamma=ab.cbfc_gamma, temp=cfg.cbfc_temp)
        mu = ab.contrast_mu
    elif ab.contrastive == 'bcl':
        contrast = BCLLoss(temp=cfg.cbfc_temp, dialogue_scoped=True)
        mu = ab.contrast_mu
    elif ab.contrastive == 'bcl_global':
        contrast = BCLLoss(temp=cfg.cbfc_temp, dialogue_scoped=False)
        mu = ab.contrast_mu
    pack = {'cbce': cbce, 'contrast': contrast, 'mu': mu}
    if ab.eacl:
        eacl = EACLLoss(C, 3 * cfg.hidden).to(device)
        model._eacl = eacl
        lam = ab.eacl_lambda
        pack['extra_modules'] = [eacl]
        pack['extra_loss'] = lambda model_, z, y: lam * eacl(z, y)
    return pack

def EPOCH_TELEMETRY(model):
    """EACL mechanism check: hap/exc and ang/fru anchor cosine should drop."""
    eacl = getattr(model, '_eacl', None)
    if eacl is None:
        return {}
    with torch.no_grad():
        a = F.normalize(eacl.anchors, dim=-1)
        cosm = (a @ a.t()).cpu()
    return {'anchor_cos_hap_exc': round(float(cosm[0, 4]), 4),
            'anchor_cos_ang_fru': round(float(cosm[3, 5]), 4)}

print('M3 build_model / build_losses / telemetry defined.')
# Out:
# M3 build_model / build_losses / telemetry defined.

# %%
# ── Shared run infrastructure: per-class telemetry, multi-seed sweep, McNemar ─

SEEDS = (42, 43, 44)
N_CLS = cfg.n_classes[cfg.dataset]
EMO   = ['hap', 'sad', 'neu', 'ang', 'exc', 'fru'] if cfg.dataset == 'iemocap' \
        else [str(i) for i in range(N_CLS)]
PAIRS = {'pair_hap_exc': (0, 4), 'pair_ang_fru': (3, 5)} if cfg.dataset == 'iemocap' else {}

def _pair_metrics(pc):
    return {k: float((pc[i] + pc[j]) / 2.0) for k, (i, j) in PAIRS.items()}

def run_ablation(name, ab, epochs=ABLATION_EPOCHS, seed=ABLATION_SEED):
    """Train one variant. Per-class F1 + hard-pair F1 logged each epoch.
    Uses notebook-level build_model / build_losses and optional
    AFTER_BACKWARD(model, y) / EPOCH_TELEMETRY(model) hooks."""
    print(f'\n{"="*60}')
    print(f'  RUN: {name}  (epochs={epochs}, seed={seed})')
    print(f'{"="*60}')

    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

    model = build_model(ab).to(device)
    lp = build_losses(ab, model)
    params = list(model.parameters())
    for m_ in lp.get('extra_modules', []):
        m_.to(device); params += list(m_.parameters())
    n_params = sum(p.numel() for p in params if p.requires_grad)
    print(f'  #params: {n_params/1e6:.2f}M   ab={ab}')

    cbce      = lp['cbce']
    contrast  = lp.get('contrast')
    mu        = lp.get('mu', 0.0)
    extra_loss = lp.get('extra_loss')
    after_bw  = globals().get('AFTER_BACKWARD')
    telem     = globals().get('EPOCH_TELEMETRY')

    optim = torch.optim.AdamW(params, lr=cfg.lr, weight_decay=cfg.weight_decay)
    sched = make_ablation_scheduler(optim, cfg, steps_per_epoch=len(train_loader), epochs=epochs)

    best_val = {'wf1': -1, 'epoch': -1}
    history  = []

    for ep in range(1, epochs + 1):
        model.train()
        t0 = time.time(); running = 0.0; nb = 0
        for batch in train_loader:
            optim.zero_grad()
            logits, z, dia = model(batch, return_repr=True)
            y = batch['labels'].to(device)
            loss = cbce(logits, y)
            if contrast is not None and mu > 0:
                loss = loss + mu * contrast(z, y, dia)
            if extra_loss is not None:
                loss = loss + extra_loss(model, z, y)
            loss.backward()
            if after_bw is not None:
                after_bw(model, y)
            nn.utils.clip_grad_norm_(params, cfg.grad_clip)
            optim.step(); sched.step()
            running += loss.item(); nb += 1
        tr_loss = running / max(1, nb)

        acc_v, wf1_v, mf1_v, *_ = evaluate(model, val_loader)
        acc_t, wf1_t, mf1_t, yt, yp, _ = evaluate(model, test_loader)
        pc = f1_score(yt, yp, average=None, labels=list(range(N_CLS)))
        pair_m = _pair_metrics(pc)
        dt = time.time() - t0

        entry = {'epoch': ep, 'tr_loss': tr_loss,
                 'val_acc': float(acc_v), 'val_wf1': float(wf1_v),
                 'test_acc': float(acc_t), 'test_wf1': float(wf1_t), 'test_mf1': float(mf1_t),
                 'test_f1_per_class': [round(float(x), 4) for x in pc], **pair_m}
        if telem is not None:
            entry.update(telem(model) or {})

        marker = ''
        if wf1_v > best_val['wf1']:
            best_val = {'wf1': wf1_v, 'epoch': ep,
                        'test_acc': float(acc_t), 'test_wf1': float(wf1_t),
                        'test_mf1': float(mf1_t),
                        'test_f1_per_class': [float(x) for x in pc], **pair_m,
                        'y_true': yt.tolist(), 'y_pred': yp.tolist()}
            torch.save(model.state_dict(), CKPT_DIR / f'{name}_bestval.pt')
            marker = '  [BEST-VAL]'

        pair_str = ' '.join(f'{k.replace("pair_","")}={v:.3f}' for k, v in pair_m.items())
        print(f'  ep{ep:02d}/{epochs} {dt:.1f}s  tr_loss={tr_loss:.4f} '
              f'val_wF1={wf1_v:.4f}  test_wF1={wf1_t:.4f} {pair_str}{marker}')
        history.append(entry)

    with open(CKPT_DIR / f'{name}_history.json', 'w') as f:
        json.dump({'history': history, 'best_val': {k: v for k, v in best_val.items()
                                                    if k not in ('y_true', 'y_pred')}}, f, indent=2)

    result = {'name': name,
              'test_acc': best_val['test_acc'], 'test_wf1': best_val['test_wf1'],
              'test_mf1': best_val['test_mf1'], 'best_val_epoch': best_val['epoch'],
              'test_f1_per_class': best_val['test_f1_per_class'],
              **{k: best_val[k] for k in PAIRS},
              'y_true': best_val['y_true'], 'y_pred': best_val['y_pred']}

    all_results = _load_results()
    all_results[name] = result
    _save_results(all_results)
    print(f'  BEST-VAL ep{best_val["epoch"]:02d}: acc={result["test_acc"]:.4f} '
          f'wF1={result["test_wf1"]:.4f} mF1={result["test_mf1"]:.4f}')
    return result

def run_sweep(name, ab, epochs=ABLATION_EPOCHS, seeds=SEEDS):
    """Multi-seed confirmation. Already-finished seeds are skipped via results file."""
    rows = []
    for s in seeds:
        key = f'{name}_s{s}'
        res = _load_results()
        rows.append(res[key] if key in res else run_ablation(key, ab, epochs=epochs, seed=s))
    agg = {k: (float(np.mean([r[k] for r in rows])), float(np.std([r[k] for r in rows])))
           for k in ('test_acc', 'test_wf1', 'test_mf1')}
    print(f'\n{name}: wF1 {agg["test_wf1"][0]:.4f}±{agg["test_wf1"][1]:.4f}  '
          f'mF1 {agg["test_mf1"][0]:.4f}±{agg["test_mf1"][1]:.4f}  '
          f'acc {agg["test_acc"][0]:.4f}±{agg["test_acc"][1]:.4f}')
    return agg

def mcnemar_vs(name_a, name_b):
    """McNemar p-value on stored test predictions (a vs b)."""
    try:
        from statsmodels.stats.contingency_tables import mcnemar
    except ImportError:
        subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'statsmodels'], check=False)
        from statsmodels.stats.contingency_tables import mcnemar
    res = _load_results()
    yt = np.array(res[name_a]['y_true'])
    pa = np.array(res[name_a]['y_pred']); pb = np.array(res[name_b]['y_pred'])
    ca, cb = pa == yt, pb == yt
    tbl = [[int((ca & cb).sum()), int((ca & ~cb).sum())],
           [int((~ca & cb).sum()), int((~ca & ~cb).sum())]]
    return float(mcnemar(tbl, exact=False, correction=True).pvalue)

print('run_ablation / run_sweep / mcnemar_vs ready.')
# Out:
# run_ablation / run_sweep / mcnemar_vs ready.

# %% [markdown]
# ## Phase 1 — 3A smoothing × class-balance grid

# %%
# ── Phase 1 (3A): label smoothing x class-balance grid — re-baselines all later runs
L_GRID_3A = {
    'L0_ls00_cbOff': AblationCfg(label_smoothing=0.0, cb_weights=False),
    'L1_ls00_cbOn':  AblationCfg(label_smoothing=0.0, cb_weights=True),
    'L2_ls01_cbOff': AblationCfg(label_smoothing=0.1, cb_weights=False),
    'L3_ls01_cbOn':  AblationCfg(label_smoothing=0.1, cb_weights=True),
}
all_results = _load_results()
for name, ab in L_GRID_3A.items():
    if name in all_results:
        print(f'[SKIP] {name}')
        continue
    run_ablation(name, ab)

# Pick the base: judged on mF1 + minority-class (hap, idx 0) F1, not wF1
res = _load_results()
print('\n3A grid (pick by mF1; hap F1 shown as the minority-dilution symptom):')
for k in L_GRID_3A:
    r = res[k]
    print(f"  {k:16s} mF1={r['test_mf1']:.4f}  wF1={r['test_wf1']:.4f}  "
          f"hap_F1={r['test_f1_per_class'][0]:.4f}")
BASE_NAME = max(L_GRID_3A, key=lambda k: res[k]['test_mf1'])
BASE_AB   = L_GRID_3A[BASE_NAME]
print(f'\n=> base config: {BASE_NAME}  ({BASE_AB})')
# Out:
# ============================================================
#   RUN: L0_ls00_cbOff  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=False, contrastive='cbfc', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
# /mnt/Work/Environments/Ubuntu/Conda/envs/hopeful/lib/python3.10/site-packages/torch/nn/modules/transformer.py:531: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
#   ep01/30 3.6s  tr_loss=2.0795 val_wF1=0.3843  test_wF1=0.2526 hap_exc=0.000 ang_fru=0.346  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.7386 val_wF1=0.4961  test_wF1=0.4995 hap_exc=0.338 ang_fru=0.528  [BEST-VAL]
#   ep03/30 3.2s  tr_loss=1.5366 val_wF1=0.5892  test_wF1=0.5791 hap_exc=0.373 ang_fru=0.569  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.4010 val_wF1=0.5916  test_wF1=0.5236 hap_exc=0.279 ang_fru=0.578  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.3454 val_wF1=0.6592  test_wF1=0.6243 hap_exc=0.430 ang_fru=0.597  [BEST-VAL]
#   ep06/30 3.4s  tr_loss=1.2501 val_wF1=0.6272  test_wF1=0.6261 hap_exc=0.488 ang_fru=0.581
#   ep07/30 3.4s  tr_loss=1.2052 val_wF1=0.6896  test_wF1=0.6429 hap_exc=0.511 ang_fru=0.635  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=1.1517 val_wF1=0.6973  test_wF1=0.6499 hap_exc=0.533 ang_fru=0.625  [BEST-VAL]
#   ep09/30 3.3s  tr_loss=1.1605 val_wF1=0.6674  test_wF1=0.6478 hap_exc=0.551 ang_fru=0.615
#   ep10/30 3.3s  tr_loss=1.0911 val_wF1=0.7001  test_wF1=0.6648 hap_exc=0.548 ang_fru=0.644  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=1.0477 val_wF1=0.7199  test_wF1=0.6686 hap_exc=0.568 ang_fru=0.635  [BEST-VAL]
#   ep12/30 3.3s  tr_loss=1.0031 val_wF1=0.7268  test_wF1=0.6675 hap_exc=0.571 ang_fru=0.639  [BEST-VAL]
#   ep13/30 3.3s  tr_loss=0.9677 val_wF1=0.7181  test_wF1=0.6766 hap_exc=0.591 ang_fru=0.645
#   ep14/30 3.3s  tr_loss=0.9493 val_wF1=0.7230  test_wF1=0.6754 hap_exc=0.564 ang_fru=0.647
#   ep15/30 3.3s  tr_loss=0.9239 val_wF1=0.7177  test_wF1=0.6529 hap_exc=0.531 ang_fru=0.637
#   ep16/30 3.3s  tr_loss=0.9094 val_wF1=0.7525  test_wF1=0.6836 hap_exc=0.573 ang_fru=0.659  [BEST-VAL]
#   ep17/30 3.3s  tr_loss=0.8903 val_wF1=0.7158  test_wF1=0.6643 hap_exc=0.553 ang_fru=0.645
#   ep18/30 3.3s  tr_loss=0.8611 val_wF1=0.7367  test_wF1=0.7015 hap_exc=0.608 ang_fru=0.667
#   ep19/30 3.3s  tr_loss=0.8528 val_wF1=0.7358  test_wF1=0.6851 hap_exc=0.599 ang_fru=0.654
#   ep20/30 3.3s  tr_loss=0.8204 val_wF1=0.7260  test_wF1=0.6895 hap_exc=0.601 ang_fru=0.647
#   ep21/30 3.3s  tr_loss=0.8176 val_wF1=0.7254  test_wF1=0.6787 hap_exc=0.583 ang_fru=0.641
#   ep22/30 3.3s  tr_loss=0.8025 val_wF1=0.7493  test_wF1=0.6925 hap_exc=0.599 ang_fru=0.660
#   ep23/30 3.3s  tr_loss=0.7888 val_wF1=0.7399  test_wF1=0.6851 hap_exc=0.592 ang_fru=0.654
#   ep24/30 3.3s  tr_loss=0.7750 val_wF1=0.7272  test_wF1=0.6824 hap_exc=0.583 ang_fru=0.648
#   ep25/30 3.4s  tr_loss=0.7690 val_wF1=0.7414  test_wF1=0.6845 hap_exc=0.591 ang_fru=0.648
#   ep26/30 3.3s  tr_loss=0.7544 val_wF1=0.7300  test_wF1=0.6743 hap_exc=0.584 ang_fru=0.636
#   ep27/30 3.3s  tr_loss=0.7649 val_wF1=0.7300  test_wF1=0.6754 hap_exc=0.581 ang_fru=0.640
#   ep28/30 3.3s  tr_loss=0.7656 val_wF1=0.7283  test_wF1=0.6819 hap_exc=0.599 ang_fru=0.638
#   ep29/30 3.3s  tr_loss=0.7616 val_wF1=0.7245  test_wF1=0.6820 hap_exc=0.597 ang_fru=0.640
#   ep30/30 3.3s  tr_loss=0.7571 val_wF1=0.7245  test_wF1=0.6807 hap_exc=0.594 ang_fru=0.640
#   BEST-VAL ep16: acc=0.6895 wF1=0.6836 mF1=0.6599
#
# ============================================================
#   RUN: L1_ls00_cbOn  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='cbfc', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=2.0676 val_wF1=0.4440  test_wF1=0.3801 hap_exc=0.349 ang_fru=0.407  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.6775 val_wF1=0.5266  test_wF1=0.5394 hap_exc=0.489 ang_fru=0.539  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.4571 val_wF1=0.5638  test_wF1=0.5777 hap_exc=0.408 ang_fru=0.561  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.3441 val_wF1=0.6185  test_wF1=0.6219 hap_exc=0.492 ang_fru=0.625  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.2247 val_wF1=0.6422  test_wF1=0.6389 hap_exc=0.560 ang_fru=0.605  [BEST-VAL]
#   ep06/30 3.3s  tr_loss=1.1912 val_wF1=0.6428  test_wF1=0.6484 hap_exc=0.568 ang_fru=0.599  [BEST-VAL]
#   ep07/30 3.3s  tr_loss=1.1515 val_wF1=0.6745  test_wF1=0.6464 hap_exc=0.563 ang_fru=0.636  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=1.0820 val_wF1=0.6789  test_wF1=0.6725 hap_exc=0.585 ang_fru=0.636  [BEST-VAL]
#   ep09/30 3.3s  tr_loss=1.0489 val_wF1=0.6587  test_wF1=0.6346 hap_exc=0.523 ang_fru=0.625
#   ep10/30 3.3s  tr_loss=1.0244 val_wF1=0.6848  test_wF1=0.6690 hap_exc=0.587 ang_fru=0.662  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=1.0337 val_wF1=0.6840  test_wF1=0.6463 hap_exc=0.561 ang_fru=0.628
#   ep12/30 3.3s  tr_loss=0.9579 val_wF1=0.6687  test_wF1=0.6573 hap_exc=0.606 ang_fru=0.604
#   ep13/30 3.4s  tr_loss=0.9261 val_wF1=0.6850  test_wF1=0.6517 hap_exc=0.529 ang_fru=0.652  [BEST-VAL]
#   ep14/30 3.3s  tr_loss=0.8879 val_wF1=0.7099  test_wF1=0.6823 hap_exc=0.599 ang_fru=0.662  [BEST-VAL]
#   ep15/30 3.3s  tr_loss=0.8804 val_wF1=0.6857  test_wF1=0.6426 hap_exc=0.530 ang_fru=0.637
#   ep16/30 3.3s  tr_loss=0.8558 val_wF1=0.7328  test_wF1=0.6829 hap_exc=0.607 ang_fru=0.658  [BEST-VAL]
#   ep17/30 3.3s  tr_loss=0.8447 val_wF1=0.7172  test_wF1=0.6594 hap_exc=0.592 ang_fru=0.643
#   ep18/30 3.3s  tr_loss=0.8305 val_wF1=0.7237  test_wF1=0.6781 hap_exc=0.600 ang_fru=0.645
#   ep19/30 3.3s  tr_loss=0.8058 val_wF1=0.7138  test_wF1=0.6679 hap_exc=0.601 ang_fru=0.632
#   ep20/30 3.3s  tr_loss=0.7783 val_wF1=0.7189  test_wF1=0.6834 hap_exc=0.626 ang_fru=0.662
#   ep21/30 3.4s  tr_loss=0.7736 val_wF1=0.7004  test_wF1=0.6708 hap_exc=0.597 ang_fru=0.638
#   ep22/30 3.4s  tr_loss=0.7570 val_wF1=0.7252  test_wF1=0.6828 hap_exc=0.600 ang_fru=0.667
#   ep23/30 3.4s  tr_loss=0.7379 val_wF1=0.7030  test_wF1=0.6821 hap_exc=0.620 ang_fru=0.651
#   ep24/30 3.4s  tr_loss=0.7344 val_wF1=0.7209  test_wF1=0.6894 hap_exc=0.609 ang_fru=0.675
#   ep25/30 3.3s  tr_loss=0.7264 val_wF1=0.7099  test_wF1=0.6877 hap_exc=0.608 ang_fru=0.668
#   ep26/30 3.4s  tr_loss=0.7125 val_wF1=0.7146  test_wF1=0.6908 hap_exc=0.627 ang_fru=0.655
#   ep27/30 3.4s  tr_loss=0.7238 val_wF1=0.7192  test_wF1=0.6801 hap_exc=0.606 ang_fru=0.652
#   ep28/30 3.4s  tr_loss=0.7209 val_wF1=0.7176  test_wF1=0.6839 hap_exc=0.611 ang_fru=0.658
#   ep29/30 3.4s  tr_loss=0.7103 val_wF1=0.7164  test_wF1=0.6841 hap_exc=0.608 ang_fru=0.659
#   ep30/30 3.4s  tr_loss=0.7164 val_wF1=0.7146  test_wF1=0.6841 hap_exc=0.605 ang_fru=0.659
#   BEST-VAL ep16: acc=0.6827 wF1=0.6829 mF1=0.6682
#
# ============================================================
#   RUN: L2_ls01_cbOff  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.1, cb_weights=False, contrastive='cbfc', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=2.0903 val_wF1=0.3712  test_wF1=0.2680 hap_exc=0.000 ang_fru=0.356  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.8332 val_wF1=0.5048  test_wF1=0.4941 hap_exc=0.385 ang_fru=0.490  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.6523 val_wF1=0.6200  test_wF1=0.5708 hap_exc=0.379 ang_fru=0.609  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.5629 val_wF1=0.6560  test_wF1=0.6173 hap_exc=0.530 ang_fru=0.538  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.5038 val_wF1=0.6458  test_wF1=0.6170 hap_exc=0.491 ang_fru=0.540
#   ep06/30 3.3s  tr_loss=1.4568 val_wF1=0.6343  test_wF1=0.6183 hap_exc=0.488 ang_fru=0.592
#   ep07/30 3.3s  tr_loss=1.3988 val_wF1=0.6974  test_wF1=0.6483 hap_exc=0.519 ang_fru=0.637  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=1.3647 val_wF1=0.6916  test_wF1=0.6509 hap_exc=0.523 ang_fru=0.611
#   ep09/30 3.3s  tr_loss=1.3666 val_wF1=0.6468  test_wF1=0.6180 hap_exc=0.497 ang_fru=0.636
#   ep10/30 3.4s  tr_loss=1.3331 val_wF1=0.6939  test_wF1=0.6594 hap_exc=0.519 ang_fru=0.619
#   ep11/30 3.4s  tr_loss=1.3071 val_wF1=0.7219  test_wF1=0.6366 hap_exc=0.499 ang_fru=0.648  [BEST-VAL]
#   ep12/30 3.4s  tr_loss=1.2673 val_wF1=0.7311  test_wF1=0.6781 hap_exc=0.591 ang_fru=0.650  [BEST-VAL]
#   ep13/30 3.3s  tr_loss=1.2534 val_wF1=0.7317  test_wF1=0.6656 hap_exc=0.550 ang_fru=0.655  [BEST-VAL]
#   ep14/30 3.3s  tr_loss=1.2286 val_wF1=0.7484  test_wF1=0.6660 hap_exc=0.557 ang_fru=0.645  [BEST-VAL]
#   ep15/30 3.3s  tr_loss=1.2073 val_wF1=0.7233  test_wF1=0.6747 hap_exc=0.574 ang_fru=0.655
#   ep16/30 3.3s  tr_loss=1.1939 val_wF1=0.7326  test_wF1=0.6806 hap_exc=0.583 ang_fru=0.678
#   ep17/30 3.3s  tr_loss=1.1740 val_wF1=0.7630  test_wF1=0.6764 hap_exc=0.581 ang_fru=0.639  [BEST-VAL]
#   ep18/30 3.3s  tr_loss=1.1515 val_wF1=0.7381  test_wF1=0.6709 hap_exc=0.565 ang_fru=0.645
#   ep19/30 3.3s  tr_loss=1.1441 val_wF1=0.7377  test_wF1=0.6727 hap_exc=0.580 ang_fru=0.644
#   ep20/30 3.4s  tr_loss=1.1222 val_wF1=0.7337  test_wF1=0.6725 hap_exc=0.572 ang_fru=0.647
#   ep21/30 3.3s  tr_loss=1.1177 val_wF1=0.7495  test_wF1=0.6708 hap_exc=0.577 ang_fru=0.640
#   ep22/30 3.4s  tr_loss=1.1046 val_wF1=0.7446  test_wF1=0.6814 hap_exc=0.570 ang_fru=0.653
#   ep23/30 3.4s  tr_loss=1.0958 val_wF1=0.7579  test_wF1=0.6742 hap_exc=0.571 ang_fru=0.641
#   ep24/30 3.4s  tr_loss=1.0887 val_wF1=0.7413  test_wF1=0.6701 hap_exc=0.568 ang_fru=0.637
#   ep25/30 3.3s  tr_loss=1.0820 val_wF1=0.7483  test_wF1=0.6736 hap_exc=0.577 ang_fru=0.638
#   ep26/30 3.3s  tr_loss=1.0739 val_wF1=0.7478  test_wF1=0.6754 hap_exc=0.577 ang_fru=0.641
#   ep27/30 3.3s  tr_loss=1.0792 val_wF1=0.7412  test_wF1=0.6773 hap_exc=0.580 ang_fru=0.644
#   ep28/30 3.4s  tr_loss=1.0761 val_wF1=0.7475  test_wF1=0.6767 hap_exc=0.576 ang_fru=0.643
#   ep29/30 3.2s  tr_loss=1.0717 val_wF1=0.7444  test_wF1=0.6781 hap_exc=0.575 ang_fru=0.648
#   ep30/30 3.2s  tr_loss=1.0725 val_wF1=0.7444  test_wF1=0.6794 hap_exc=0.575 ang_fru=0.650
#   BEST-VAL ep17: acc=0.6778 wF1=0.6764 mF1=0.6590
#
# ============================================================
#   RUN: L3_ls01_cbOn  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.1, cb_weights=True, contrastive='cbfc', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.3s  tr_loss=2.0893 val_wF1=0.4314  test_wF1=0.3777 hap_exc=0.353 ang_fru=0.373  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.7985 val_wF1=0.5082  test_wF1=0.4562 hap_exc=0.346 ang_fru=0.526  [BEST-VAL]
#   ep03/30 3.4s  tr_loss=1.6392 val_wF1=0.5874  test_wF1=0.5886 hap_exc=0.405 ang_fru=0.582  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.5459 val_wF1=0.6236  test_wF1=0.5577 hap_exc=0.345 ang_fru=0.583  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.4720 val_wF1=0.6662  test_wF1=0.6490 hap_exc=0.547 ang_fru=0.589  [BEST-VAL]
#   ep06/30 3.3s  tr_loss=1.4377 val_wF1=0.6339  test_wF1=0.6066 hap_exc=0.467 ang_fru=0.595
#   ep07/30 3.3s  tr_loss=1.3864 val_wF1=0.6893  test_wF1=0.6603 hap_exc=0.569 ang_fru=0.627  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=1.3516 val_wF1=0.6718  test_wF1=0.6599 hap_exc=0.577 ang_fru=0.624
#   ep09/30 3.3s  tr_loss=1.3477 val_wF1=0.6759  test_wF1=0.6353 hap_exc=0.514 ang_fru=0.642
#   ep10/30 3.3s  tr_loss=1.3095 val_wF1=0.7202  test_wF1=0.6818 hap_exc=0.611 ang_fru=0.651  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=1.2898 val_wF1=0.6606  test_wF1=0.6551 hap_exc=0.585 ang_fru=0.628
#   ep12/30 3.3s  tr_loss=1.2579 val_wF1=0.6899  test_wF1=0.6658 hap_exc=0.594 ang_fru=0.634
#   ep13/30 3.3s  tr_loss=1.2370 val_wF1=0.6851  test_wF1=0.6466 hap_exc=0.519 ang_fru=0.655
#   ep14/30 3.3s  tr_loss=1.2209 val_wF1=0.7391  test_wF1=0.6767 hap_exc=0.591 ang_fru=0.653  [BEST-VAL]
#   ep15/30 3.3s  tr_loss=1.2069 val_wF1=0.7008  test_wF1=0.6463 hap_exc=0.526 ang_fru=0.649
#   ep16/30 3.3s  tr_loss=1.1805 val_wF1=0.7355  test_wF1=0.6815 hap_exc=0.587 ang_fru=0.673
#   ep17/30 3.3s  tr_loss=1.1705 val_wF1=0.7246  test_wF1=0.6697 hap_exc=0.597 ang_fru=0.634
#   ep18/30 3.3s  tr_loss=1.1523 val_wF1=0.7236  test_wF1=0.6734 hap_exc=0.587 ang_fru=0.645
#   ep19/30 3.3s  tr_loss=1.1390 val_wF1=0.7207  test_wF1=0.6704 hap_exc=0.574 ang_fru=0.648
#   ep20/30 3.2s  tr_loss=1.1208 val_wF1=0.7276  test_wF1=0.6677 hap_exc=0.576 ang_fru=0.655
#   ep21/30 3.2s  tr_loss=1.1131 val_wF1=0.7212  test_wF1=0.6655 hap_exc=0.586 ang_fru=0.634
#   ep22/30 3.2s  tr_loss=1.1000 val_wF1=0.7282  test_wF1=0.6734 hap_exc=0.574 ang_fru=0.659
#   ep23/30 3.2s  tr_loss=1.0870 val_wF1=0.7205  test_wF1=0.6711 hap_exc=0.586 ang_fru=0.642
#   ep24/30 3.3s  tr_loss=1.0844 val_wF1=0.7271  test_wF1=0.6714 hap_exc=0.573 ang_fru=0.652
#   ep25/30 3.3s  tr_loss=1.0820 val_wF1=0.7233  test_wF1=0.6714 hap_exc=0.568 ang_fru=0.653
#   ep26/30 3.3s  tr_loss=1.0734 val_wF1=0.7289  test_wF1=0.6764 hap_exc=0.593 ang_fru=0.647
#   ep27/30 3.3s  tr_loss=1.0772 val_wF1=0.7310  test_wF1=0.6703 hap_exc=0.574 ang_fru=0.646
#   ep28/30 3.4s  tr_loss=1.0750 val_wF1=0.7325  test_wF1=0.6691 hap_exc=0.564 ang_fru=0.647
#   ep29/30 3.3s  tr_loss=1.0663 val_wF1=0.7326  test_wF1=0.6709 hap_exc=0.571 ang_fru=0.647
#   ep30/30 3.3s  tr_loss=1.0737 val_wF1=0.7326  test_wF1=0.6702 hap_exc=0.570 ang_fru=0.645
#   BEST-VAL ep14: acc=0.6771 wF1=0.6767 mF1=0.6583
#
# 3A grid (pick by mF1; hap F1 shown as the minority-dilution symptom):
#   L0_ls00_cbOff    mF1=0.6599  wF1=0.6836  hap_F1=0.3983
#   L1_ls00_cbOn     mF1=0.6682  wF1=0.6829  hap_F1=0.4858
#   L2_ls01_cbOff    mF1=0.6590  wF1=0.6764  hap_F1=0.4483
#   L3_ls01_cbOn     mF1=0.6583  wF1=0.6767  hap_F1=0.4338
#
# => base config: L1_ls00_cbOn  (AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='cbfc', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2))

# %% [markdown]
# ## Phase 2 — contrastive design (CBFC γ / BCL)

# %%
# ── Phase 2: CBFC gamma sweep (L4) + BCL in both scopes (L5), on the 3A base
all_results = _load_results()
phase2 = {}
for g in (0.0, 1.0, 2.0):
    phase2[f'L4_cbfc_g{g:g}'] = replace(BASE_AB, contrastive='cbfc', cbfc_gamma=g)
phase2['L5_bcl_dia']    = replace(BASE_AB, contrastive='bcl')
phase2['L5_bcl_global'] = replace(BASE_AB, contrastive='bcl_global')
phase2['L5_contrast_off'] = replace(BASE_AB, contrastive='off')

for name, ab in phase2.items():
    if name in all_results:
        print(f'[SKIP] {name}')
        continue
    run_ablation(name, ab)

res = _load_results()
print('\nPhase 2 (contrastive design):')
for k in phase2:
    r = res[k]
    print(f"  {k:18s} wF1={r['test_wf1']:.4f}  mF1={r['test_mf1']:.4f}  "
          f"hap_exc={r['pair_hap_exc']:.4f}  ang_fru={r['pair_ang_fru']:.4f}")
CONTRAST_NAME = max(phase2, key=lambda k: res[k]['test_wf1'])
CONTRAST_AB   = phase2[CONTRAST_NAME]
print(f'\n=> contrastive winner: {CONTRAST_NAME}')
# Out:
# ============================================================
#   RUN: L4_cbfc_g0  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='cbfc', cbfc_gamma=0.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=2.0828 val_wF1=0.4454  test_wF1=0.3818 hap_exc=0.364 ang_fru=0.412  [BEST-VAL]
#   ep02/30 3.5s  tr_loss=1.6926 val_wF1=0.5174  test_wF1=0.5309 hap_exc=0.482 ang_fru=0.540  [BEST-VAL]
#   ep03/30 3.4s  tr_loss=1.4743 val_wF1=0.5686  test_wF1=0.5803 hap_exc=0.406 ang_fru=0.565  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.3571 val_wF1=0.6298  test_wF1=0.6160 hap_exc=0.478 ang_fru=0.622  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.2392 val_wF1=0.6401  test_wF1=0.6343 hap_exc=0.554 ang_fru=0.597  [BEST-VAL]
#   ep06/30 3.4s  tr_loss=1.2083 val_wF1=0.6549  test_wF1=0.6501 hap_exc=0.578 ang_fru=0.603  [BEST-VAL]
#   ep07/30 3.4s  tr_loss=1.1576 val_wF1=0.6821  test_wF1=0.6539 hap_exc=0.576 ang_fru=0.651  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=1.1047 val_wF1=0.7055  test_wF1=0.6813 hap_exc=0.595 ang_fru=0.658  [BEST-VAL]
#   ep09/30 3.3s  tr_loss=1.0767 val_wF1=0.6513  test_wF1=0.6377 hap_exc=0.576 ang_fru=0.616
#   ep10/30 3.6s  tr_loss=1.0324 val_wF1=0.6997  test_wF1=0.6694 hap_exc=0.603 ang_fru=0.650
#   ep11/30 3.3s  tr_loss=1.0284 val_wF1=0.6686  test_wF1=0.6525 hap_exc=0.589 ang_fru=0.616
#   ep12/30 3.3s  tr_loss=0.9840 val_wF1=0.6623  test_wF1=0.6542 hap_exc=0.586 ang_fru=0.612
#   ep13/30 3.3s  tr_loss=0.9617 val_wF1=0.6852  test_wF1=0.6589 hap_exc=0.578 ang_fru=0.637
#   ep14/30 3.4s  tr_loss=0.9174 val_wF1=0.7210  test_wF1=0.6791 hap_exc=0.606 ang_fru=0.649  [BEST-VAL]
#   ep15/30 3.4s  tr_loss=0.9005 val_wF1=0.6844  test_wF1=0.6427 hap_exc=0.538 ang_fru=0.639
#   ep16/30 3.4s  tr_loss=0.8927 val_wF1=0.7233  test_wF1=0.6802 hap_exc=0.614 ang_fru=0.650  [BEST-VAL]
#   ep17/30 3.5s  tr_loss=0.8924 val_wF1=0.7147  test_wF1=0.6569 hap_exc=0.592 ang_fru=0.628
#   ep18/30 3.4s  tr_loss=0.8524 val_wF1=0.7190  test_wF1=0.6743 hap_exc=0.595 ang_fru=0.656
#   ep19/30 3.5s  tr_loss=0.8342 val_wF1=0.7362  test_wF1=0.6794 hap_exc=0.619 ang_fru=0.658  [BEST-VAL]
#   ep20/30 3.2s  tr_loss=0.8126 val_wF1=0.6971  test_wF1=0.6782 hap_exc=0.615 ang_fru=0.650
#   ep21/30 3.2s  tr_loss=0.7903 val_wF1=0.7154  test_wF1=0.6825 hap_exc=0.600 ang_fru=0.663
#   ep22/30 3.2s  tr_loss=0.7850 val_wF1=0.7129  test_wF1=0.6759 hap_exc=0.633 ang_fru=0.651
#   ep23/30 3.4s  tr_loss=0.7749 val_wF1=0.7222  test_wF1=0.6859 hap_exc=0.619 ang_fru=0.665
#   ep24/30 3.4s  tr_loss=0.7607 val_wF1=0.7141  test_wF1=0.6819 hap_exc=0.619 ang_fru=0.657
#   ep25/30 3.3s  tr_loss=0.7564 val_wF1=0.7169  test_wF1=0.6815 hap_exc=0.610 ang_fru=0.659
#   ep26/30 3.3s  tr_loss=0.7429 val_wF1=0.7117  test_wF1=0.6789 hap_exc=0.606 ang_fru=0.659
#   ep27/30 3.4s  tr_loss=0.7504 val_wF1=0.7256  test_wF1=0.6860 hap_exc=0.615 ang_fru=0.662
#   ep28/30 3.3s  tr_loss=0.7468 val_wF1=0.7290  test_wF1=0.6855 hap_exc=0.612 ang_fru=0.661
#   ep29/30 3.3s  tr_loss=0.7394 val_wF1=0.7204  test_wF1=0.6823 hap_exc=0.611 ang_fru=0.659
#   ep30/30 3.3s  tr_loss=0.7427 val_wF1=0.7172  test_wF1=0.6847 hap_exc=0.616 ang_fru=0.660
#   BEST-VAL ep19: acc=0.6759 wF1=0.6794 mF1=0.6686
#
# ============================================================
#   RUN: L4_cbfc_g1  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='cbfc', cbfc_gamma=1.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=2.0745 val_wF1=0.4454  test_wF1=0.3800 hap_exc=0.357 ang_fru=0.410  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.6840 val_wF1=0.5311  test_wF1=0.5354 hap_exc=0.482 ang_fru=0.541  [BEST-VAL]
#   ep03/30 3.4s  tr_loss=1.4656 val_wF1=0.5623  test_wF1=0.5824 hap_exc=0.409 ang_fru=0.573  [BEST-VAL]
#   ep04/30 3.5s  tr_loss=1.3503 val_wF1=0.6157  test_wF1=0.6087 hap_exc=0.472 ang_fru=0.614  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.2315 val_wF1=0.6506  test_wF1=0.6392 hap_exc=0.563 ang_fru=0.604  [BEST-VAL]
#   ep06/30 3.3s  tr_loss=1.2041 val_wF1=0.6539  test_wF1=0.6483 hap_exc=0.564 ang_fru=0.618  [BEST-VAL]
#   ep07/30 3.3s  tr_loss=1.1671 val_wF1=0.6311  test_wF1=0.6373 hap_exc=0.551 ang_fru=0.605
#   ep08/30 3.3s  tr_loss=1.1013 val_wF1=0.6400  test_wF1=0.6547 hap_exc=0.580 ang_fru=0.610
#   ep09/30 3.1s  tr_loss=1.1056 val_wF1=0.6073  test_wF1=0.5923 hap_exc=0.523 ang_fru=0.600
#   ep10/30 3.0s  tr_loss=1.0757 val_wF1=0.6859  test_wF1=0.6777 hap_exc=0.567 ang_fru=0.654  [BEST-VAL]
#   ep11/30 3.0s  tr_loss=1.0366 val_wF1=0.6841  test_wF1=0.6266 hap_exc=0.477 ang_fru=0.637
#   ep12/30 3.0s  tr_loss=0.9896 val_wF1=0.7034  test_wF1=0.6654 hap_exc=0.562 ang_fru=0.638  [BEST-VAL]
#   ep13/30 3.1s  tr_loss=0.9554 val_wF1=0.6860  test_wF1=0.6476 hap_exc=0.550 ang_fru=0.630
#   ep14/30 3.0s  tr_loss=0.9527 val_wF1=0.7164  test_wF1=0.6764 hap_exc=0.581 ang_fru=0.672  [BEST-VAL]
#   ep15/30 3.0s  tr_loss=0.9224 val_wF1=0.6780  test_wF1=0.6581 hap_exc=0.571 ang_fru=0.653
#   ep16/30 3.1s  tr_loss=0.8936 val_wF1=0.7179  test_wF1=0.6822 hap_exc=0.599 ang_fru=0.674  [BEST-VAL]
#   ep17/30 3.2s  tr_loss=0.8629 val_wF1=0.7156  test_wF1=0.6785 hap_exc=0.592 ang_fru=0.672
#   ep18/30 3.0s  tr_loss=0.8375 val_wF1=0.7075  test_wF1=0.6833 hap_exc=0.613 ang_fru=0.663
#   ep19/30 3.0s  tr_loss=0.8142 val_wF1=0.7043  test_wF1=0.6747 hap_exc=0.597 ang_fru=0.664
#   ep20/30 3.0s  tr_loss=0.7976 val_wF1=0.7239  test_wF1=0.6827 hap_exc=0.608 ang_fru=0.676  [BEST-VAL]
#   ep21/30 3.0s  tr_loss=0.7789 val_wF1=0.7147  test_wF1=0.6762 hap_exc=0.607 ang_fru=0.652
#   ep22/30 3.0s  tr_loss=0.7716 val_wF1=0.7291  test_wF1=0.6848 hap_exc=0.628 ang_fru=0.666  [BEST-VAL]
#   ep23/30 3.0s  tr_loss=0.7660 val_wF1=0.7194  test_wF1=0.6793 hap_exc=0.609 ang_fru=0.660
#   ep24/30 3.0s  tr_loss=0.7539 val_wF1=0.7147  test_wF1=0.6842 hap_exc=0.620 ang_fru=0.661
#   ep25/30 3.0s  tr_loss=0.7492 val_wF1=0.7218  test_wF1=0.6855 hap_exc=0.618 ang_fru=0.664
#   ep26/30 3.0s  tr_loss=0.7359 val_wF1=0.7094  test_wF1=0.6812 hap_exc=0.614 ang_fru=0.660
#   ep27/30 3.0s  tr_loss=0.7358 val_wF1=0.7112  test_wF1=0.6831 hap_exc=0.613 ang_fru=0.662
#   ep28/30 3.0s  tr_loss=0.7344 val_wF1=0.7180  test_wF1=0.6803 hap_exc=0.610 ang_fru=0.662
#   ep29/30 3.0s  tr_loss=0.7321 val_wF1=0.7164  test_wF1=0.6832 hap_exc=0.613 ang_fru=0.664
#   ep30/30 3.0s  tr_loss=0.7317 val_wF1=0.7164  test_wF1=0.6826 hap_exc=0.611 ang_fru=0.664
#   BEST-VAL ep22: acc=0.6821 wF1=0.6848 mF1=0.6747
#
# ============================================================
#   RUN: L4_cbfc_g2  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='cbfc', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.0s  tr_loss=2.0676 val_wF1=0.4440  test_wF1=0.3801 hap_exc=0.349 ang_fru=0.407  [BEST-VAL]
#   ep02/30 3.1s  tr_loss=1.6775 val_wF1=0.5266  test_wF1=0.5394 hap_exc=0.489 ang_fru=0.539  [BEST-VAL]
#   ep03/30 3.0s  tr_loss=1.4571 val_wF1=0.5638  test_wF1=0.5772 hap_exc=0.407 ang_fru=0.561  [BEST-VAL]
#   ep04/30 3.0s  tr_loss=1.3440 val_wF1=0.6185  test_wF1=0.6224 hap_exc=0.496 ang_fru=0.623  [BEST-VAL]
#   ep05/30 3.0s  tr_loss=1.2246 val_wF1=0.6405  test_wF1=0.6376 hap_exc=0.560 ang_fru=0.603  [BEST-VAL]
#   ep06/30 3.3s  tr_loss=1.1912 val_wF1=0.6428  test_wF1=0.6484 hap_exc=0.568 ang_fru=0.599  [BEST-VAL]
#   ep07/30 3.3s  tr_loss=1.1525 val_wF1=0.6683  test_wF1=0.6447 hap_exc=0.563 ang_fru=0.634  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=1.0831 val_wF1=0.6789  test_wF1=0.6727 hap_exc=0.580 ang_fru=0.637  [BEST-VAL]
#   ep09/30 3.3s  tr_loss=1.0505 val_wF1=0.6597  test_wF1=0.6305 hap_exc=0.519 ang_fru=0.621
#   ep10/30 3.4s  tr_loss=1.0248 val_wF1=0.6867  test_wF1=0.6660 hap_exc=0.589 ang_fru=0.654  [BEST-VAL]
#   ep11/30 3.4s  tr_loss=1.0316 val_wF1=0.6875  test_wF1=0.6451 hap_exc=0.557 ang_fru=0.631  [BEST-VAL]
#   ep12/30 3.4s  tr_loss=0.9611 val_wF1=0.6870  test_wF1=0.6602 hap_exc=0.587 ang_fru=0.623
#   ep13/30 3.3s  tr_loss=0.9254 val_wF1=0.6771  test_wF1=0.6496 hap_exc=0.526 ang_fru=0.649
#   ep14/30 3.4s  tr_loss=0.8954 val_wF1=0.7011  test_wF1=0.6797 hap_exc=0.593 ang_fru=0.650  [BEST-VAL]
#   ep15/30 3.3s  tr_loss=0.8795 val_wF1=0.6873  test_wF1=0.6505 hap_exc=0.563 ang_fru=0.619
#   ep16/30 3.3s  tr_loss=0.8531 val_wF1=0.7163  test_wF1=0.6849 hap_exc=0.594 ang_fru=0.663  [BEST-VAL]
#   ep17/30 3.3s  tr_loss=0.8387 val_wF1=0.7179  test_wF1=0.6713 hap_exc=0.610 ang_fru=0.645  [BEST-VAL]
#   ep18/30 3.4s  tr_loss=0.8184 val_wF1=0.7167  test_wF1=0.6849 hap_exc=0.594 ang_fru=0.669
#   ep19/30 3.3s  tr_loss=0.7884 val_wF1=0.7252  test_wF1=0.6707 hap_exc=0.597 ang_fru=0.641  [BEST-VAL]
#   ep20/30 3.3s  tr_loss=0.7669 val_wF1=0.7322  test_wF1=0.6804 hap_exc=0.608 ang_fru=0.665  [BEST-VAL]
#   ep21/30 3.4s  tr_loss=0.7571 val_wF1=0.7131  test_wF1=0.6776 hap_exc=0.601 ang_fru=0.647
#   ep22/30 3.3s  tr_loss=0.7514 val_wF1=0.7293  test_wF1=0.6896 hap_exc=0.616 ang_fru=0.667
#   ep23/30 3.3s  tr_loss=0.7479 val_wF1=0.7051  test_wF1=0.6845 hap_exc=0.598 ang_fru=0.661
#   ep24/30 3.3s  tr_loss=0.7308 val_wF1=0.7291  test_wF1=0.6788 hap_exc=0.601 ang_fru=0.656
#   ep25/30 3.4s  tr_loss=0.7262 val_wF1=0.7078  test_wF1=0.6831 hap_exc=0.608 ang_fru=0.660
#   ep26/30 3.4s  tr_loss=0.7162 val_wF1=0.7170  test_wF1=0.6798 hap_exc=0.603 ang_fru=0.658
#   ep27/30 3.4s  tr_loss=0.7127 val_wF1=0.7189  test_wF1=0.6800 hap_exc=0.604 ang_fru=0.657
#   ep28/30 3.3s  tr_loss=0.7168 val_wF1=0.7190  test_wF1=0.6819 hap_exc=0.608 ang_fru=0.656
#   ep29/30 3.3s  tr_loss=0.7080 val_wF1=0.7189  test_wF1=0.6798 hap_exc=0.603 ang_fru=0.655
#   ep30/30 3.3s  tr_loss=0.7101 val_wF1=0.7207  test_wF1=0.6803 hap_exc=0.603 ang_fru=0.656
#   BEST-VAL ep20: acc=0.6759 wF1=0.6804 mF1=0.6670
#
# ============================================================
#   RUN: L5_bcl_dia  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='bcl', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.3s  tr_loss=1.8277 val_wF1=0.4591  test_wF1=0.3099 hap_exc=0.145 ang_fru=0.383  [BEST-VAL]
#   ep02/30 3.3s  tr_loss=1.4254 val_wF1=0.5482  test_wF1=0.5357 hap_exc=0.483 ang_fru=0.500  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.1903 val_wF1=0.6089  test_wF1=0.5725 hap_exc=0.540 ang_fru=0.537  [BEST-VAL]
#   ep04/30 3.2s  tr_loss=1.1026 val_wF1=0.6013  test_wF1=0.5864 hap_exc=0.464 ang_fru=0.585
#   ep05/30 3.2s  tr_loss=1.0128 val_wF1=0.6273  test_wF1=0.6127 hap_exc=0.484 ang_fru=0.563  [BEST-VAL]
#   ep06/30 3.3s  tr_loss=0.9624 val_wF1=0.5985  test_wF1=0.6372 hap_exc=0.555 ang_fru=0.592
#   ep07/30 3.2s  tr_loss=0.9031 val_wF1=0.6529  test_wF1=0.6421 hap_exc=0.549 ang_fru=0.635  [BEST-VAL]
#   ep08/30 3.2s  tr_loss=0.8542 val_wF1=0.6764  test_wF1=0.6627 hap_exc=0.572 ang_fru=0.615  [BEST-VAL]
#   ep09/30 3.2s  tr_loss=0.8388 val_wF1=0.6310  test_wF1=0.6073 hap_exc=0.467 ang_fru=0.627
#   ep10/30 3.3s  tr_loss=0.8084 val_wF1=0.6962  test_wF1=0.6763 hap_exc=0.602 ang_fru=0.645  [BEST-VAL]
#   ep11/30 3.2s  tr_loss=0.7826 val_wF1=0.6869  test_wF1=0.6512 hap_exc=0.592 ang_fru=0.638
#   ep12/30 3.2s  tr_loss=0.7188 val_wF1=0.7051  test_wF1=0.6838 hap_exc=0.623 ang_fru=0.658  [BEST-VAL]
#   ep13/30 3.3s  tr_loss=0.6994 val_wF1=0.6984  test_wF1=0.6450 hap_exc=0.544 ang_fru=0.631
#   ep14/30 3.3s  tr_loss=0.6720 val_wF1=0.7235  test_wF1=0.6889 hap_exc=0.619 ang_fru=0.670  [BEST-VAL]
#   ep15/30 3.3s  tr_loss=0.6557 val_wF1=0.6715  test_wF1=0.6546 hap_exc=0.593 ang_fru=0.630
#   ep16/30 3.3s  tr_loss=0.6487 val_wF1=0.7028  test_wF1=0.6628 hap_exc=0.575 ang_fru=0.646
#   ep17/30 3.4s  tr_loss=0.6524 val_wF1=0.7058  test_wF1=0.6719 hap_exc=0.600 ang_fru=0.655
#   ep18/30 3.3s  tr_loss=0.6137 val_wF1=0.6950  test_wF1=0.6717 hap_exc=0.595 ang_fru=0.655
#   ep19/30 3.3s  tr_loss=0.5743 val_wF1=0.7238  test_wF1=0.6767 hap_exc=0.603 ang_fru=0.667  [BEST-VAL]
#   ep20/30 3.3s  tr_loss=0.5621 val_wF1=0.7104  test_wF1=0.6664 hap_exc=0.575 ang_fru=0.664
#   ep21/30 3.3s  tr_loss=0.5450 val_wF1=0.7053  test_wF1=0.6755 hap_exc=0.587 ang_fru=0.669
#   ep22/30 3.3s  tr_loss=0.5299 val_wF1=0.7152  test_wF1=0.6861 hap_exc=0.624 ang_fru=0.671
#   ep23/30 3.3s  tr_loss=0.5253 val_wF1=0.7181  test_wF1=0.6766 hap_exc=0.587 ang_fru=0.678
#   ep24/30 3.3s  tr_loss=0.5019 val_wF1=0.7229  test_wF1=0.6753 hap_exc=0.601 ang_fru=0.662
#   ep25/30 3.3s  tr_loss=0.5078 val_wF1=0.7240  test_wF1=0.6770 hap_exc=0.601 ang_fru=0.664  [BEST-VAL]
#   ep26/30 3.3s  tr_loss=0.4939 val_wF1=0.7129  test_wF1=0.6780 hap_exc=0.612 ang_fru=0.660
#   ep27/30 3.3s  tr_loss=0.4938 val_wF1=0.7112  test_wF1=0.6804 hap_exc=0.600 ang_fru=0.670
#   ep28/30 3.3s  tr_loss=0.4986 val_wF1=0.7186  test_wF1=0.6801 hap_exc=0.599 ang_fru=0.669
#   ep29/30 3.3s  tr_loss=0.4864 val_wF1=0.7132  test_wF1=0.6801 hap_exc=0.590 ang_fru=0.674
#   ep30/30 3.3s  tr_loss=0.4897 val_wF1=0.7114  test_wF1=0.6788 hap_exc=0.590 ang_fru=0.673
#   BEST-VAL ep25: acc=0.6722 wF1=0.6770 mF1=0.6654
#
# ============================================================
#   RUN: L5_bcl_global  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='bcl_global', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=1.8796 val_wF1=0.4200  test_wF1=0.3450 hap_exc=0.282 ang_fru=0.371  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.5099 val_wF1=0.4818  test_wF1=0.4797 hap_exc=0.443 ang_fru=0.505  [BEST-VAL]
#   ep03/30 3.4s  tr_loss=1.2628 val_wF1=0.4783  test_wF1=0.5435 hap_exc=0.491 ang_fru=0.440
#   ep04/30 3.3s  tr_loss=1.1591 val_wF1=0.6282  test_wF1=0.6306 hap_exc=0.548 ang_fru=0.584  [BEST-VAL]
#   ep05/30 3.4s  tr_loss=1.0570 val_wF1=0.6754  test_wF1=0.6413 hap_exc=0.541 ang_fru=0.611  [BEST-VAL]
#   ep06/30 3.4s  tr_loss=1.0180 val_wF1=0.6255  test_wF1=0.6076 hap_exc=0.459 ang_fru=0.601
#   ep07/30 3.3s  tr_loss=0.9334 val_wF1=0.6645  test_wF1=0.6485 hap_exc=0.536 ang_fru=0.635
#   ep08/30 3.4s  tr_loss=0.8848 val_wF1=0.7022  test_wF1=0.6691 hap_exc=0.591 ang_fru=0.632  [BEST-VAL]
#   ep09/30 3.4s  tr_loss=0.8644 val_wF1=0.6485  test_wF1=0.6274 hap_exc=0.550 ang_fru=0.588
#   ep10/30 3.4s  tr_loss=0.8186 val_wF1=0.6826  test_wF1=0.6653 hap_exc=0.600 ang_fru=0.650
#   ep11/30 3.4s  tr_loss=0.8141 val_wF1=0.7037  test_wF1=0.6648 hap_exc=0.597 ang_fru=0.642  [BEST-VAL]
#   ep12/30 3.4s  tr_loss=0.7520 val_wF1=0.6934  test_wF1=0.6814 hap_exc=0.611 ang_fru=0.654
#   ep13/30 3.4s  tr_loss=0.7157 val_wF1=0.6584  test_wF1=0.6354 hap_exc=0.515 ang_fru=0.637
#   ep14/30 3.4s  tr_loss=0.6850 val_wF1=0.7078  test_wF1=0.6774 hap_exc=0.635 ang_fru=0.632  [BEST-VAL]
#   ep15/30 3.4s  tr_loss=0.6741 val_wF1=0.6969  test_wF1=0.6672 hap_exc=0.590 ang_fru=0.644
#   ep16/30 3.4s  tr_loss=0.6558 val_wF1=0.7101  test_wF1=0.6807 hap_exc=0.600 ang_fru=0.661  [BEST-VAL]
#   ep17/30 3.4s  tr_loss=0.6385 val_wF1=0.7302  test_wF1=0.6825 hap_exc=0.617 ang_fru=0.652  [BEST-VAL]
#   ep18/30 3.4s  tr_loss=0.6122 val_wF1=0.7142  test_wF1=0.6752 hap_exc=0.597 ang_fru=0.654
#   ep19/30 3.4s  tr_loss=0.5845 val_wF1=0.7228  test_wF1=0.6852 hap_exc=0.600 ang_fru=0.676
#   ep20/30 3.4s  tr_loss=0.5657 val_wF1=0.7270  test_wF1=0.6881 hap_exc=0.622 ang_fru=0.672
#   ep21/30 3.4s  tr_loss=0.5519 val_wF1=0.7198  test_wF1=0.6749 hap_exc=0.600 ang_fru=0.654
#   ep22/30 3.4s  tr_loss=0.5507 val_wF1=0.7359  test_wF1=0.6931 hap_exc=0.636 ang_fru=0.677  [BEST-VAL]
#   ep23/30 3.4s  tr_loss=0.5420 val_wF1=0.7144  test_wF1=0.6863 hap_exc=0.620 ang_fru=0.662
#   ep24/30 3.5s  tr_loss=0.5256 val_wF1=0.7379  test_wF1=0.6903 hap_exc=0.629 ang_fru=0.667  [BEST-VAL]
#   ep25/30 3.4s  tr_loss=0.5159 val_wF1=0.7252  test_wF1=0.6843 hap_exc=0.608 ang_fru=0.665
#   ep26/30 3.4s  tr_loss=0.5101 val_wF1=0.7352  test_wF1=0.6929 hap_exc=0.619 ang_fru=0.675
#   ep27/30 3.4s  tr_loss=0.5092 val_wF1=0.7427  test_wF1=0.6880 hap_exc=0.617 ang_fru=0.670  [BEST-VAL]
#   ep28/30 3.4s  tr_loss=0.5093 val_wF1=0.7306  test_wF1=0.6891 hap_exc=0.618 ang_fru=0.670
#   ep29/30 3.4s  tr_loss=0.4978 val_wF1=0.7272  test_wF1=0.6890 hap_exc=0.617 ang_fru=0.667
#   ep30/30 3.4s  tr_loss=0.5086 val_wF1=0.7290  test_wF1=0.6883 hap_exc=0.617 ang_fru=0.666
#   BEST-VAL ep27: acc=0.6833 wF1=0.6880 mF1=0.6779
#
# ============================================================
#   RUN: L5_contrast_off  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='off', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=1.7229 val_wF1=0.4671  test_wF1=0.3854 hap_exc=0.352 ang_fru=0.436  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.3190 val_wF1=0.5403  test_wF1=0.5525 hap_exc=0.486 ang_fru=0.558  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.1062 val_wF1=0.6022  test_wF1=0.6029 hap_exc=0.431 ang_fru=0.592  [BEST-VAL]
#   ep04/30 3.4s  tr_loss=1.0007 val_wF1=0.6327  test_wF1=0.6038 hap_exc=0.480 ang_fru=0.584  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=0.8863 val_wF1=0.6609  test_wF1=0.6579 hap_exc=0.568 ang_fru=0.613  [BEST-VAL]
#   ep06/30 3.4s  tr_loss=0.8781 val_wF1=0.6000  test_wF1=0.5960 hap_exc=0.429 ang_fru=0.590
#   ep07/30 3.3s  tr_loss=0.8024 val_wF1=0.6456  test_wF1=0.6190 hap_exc=0.470 ang_fru=0.601
#   ep08/30 3.3s  tr_loss=0.7750 val_wF1=0.6666  test_wF1=0.6533 hap_exc=0.550 ang_fru=0.613  [BEST-VAL]
#   ep09/30 3.4s  tr_loss=0.7829 val_wF1=0.6506  test_wF1=0.6240 hap_exc=0.546 ang_fru=0.598
#   ep10/30 3.4s  tr_loss=0.7097 val_wF1=0.6934  test_wF1=0.6791 hap_exc=0.615 ang_fru=0.641  [BEST-VAL]
#   ep11/30 3.4s  tr_loss=0.6997 val_wF1=0.6536  test_wF1=0.6444 hap_exc=0.556 ang_fru=0.615
#   ep12/30 3.4s  tr_loss=0.6397 val_wF1=0.6853  test_wF1=0.6786 hap_exc=0.599 ang_fru=0.641
#   ep13/30 3.4s  tr_loss=0.6182 val_wF1=0.6800  test_wF1=0.6458 hap_exc=0.547 ang_fru=0.647
#   ep14/30 3.4s  tr_loss=0.5852 val_wF1=0.7091  test_wF1=0.6826 hap_exc=0.609 ang_fru=0.652  [BEST-VAL]
#   ep15/30 3.2s  tr_loss=0.5772 val_wF1=0.6685  test_wF1=0.6293 hap_exc=0.492 ang_fru=0.640
#   ep16/30 3.2s  tr_loss=0.5462 val_wF1=0.7260  test_wF1=0.6866 hap_exc=0.617 ang_fru=0.662  [BEST-VAL]
#   ep17/30 3.2s  tr_loss=0.5336 val_wF1=0.6958  test_wF1=0.6708 hap_exc=0.611 ang_fru=0.649
#   ep18/30 3.2s  tr_loss=0.5141 val_wF1=0.7358  test_wF1=0.6750 hap_exc=0.602 ang_fru=0.640  [BEST-VAL]
#   ep19/30 3.2s  tr_loss=0.4981 val_wF1=0.7234  test_wF1=0.6769 hap_exc=0.599 ang_fru=0.652
#   ep20/30 3.2s  tr_loss=0.4698 val_wF1=0.7168  test_wF1=0.6813 hap_exc=0.621 ang_fru=0.654
#   ep21/30 3.2s  tr_loss=0.4609 val_wF1=0.7109  test_wF1=0.6697 hap_exc=0.584 ang_fru=0.647
#   ep22/30 3.2s  tr_loss=0.4482 val_wF1=0.7166  test_wF1=0.6839 hap_exc=0.613 ang_fru=0.665
#   ep23/30 3.2s  tr_loss=0.4300 val_wF1=0.7077  test_wF1=0.6778 hap_exc=0.607 ang_fru=0.650
#   ep24/30 3.2s  tr_loss=0.4237 val_wF1=0.7095  test_wF1=0.6860 hap_exc=0.609 ang_fru=0.657
#   ep25/30 3.2s  tr_loss=0.4153 val_wF1=0.7059  test_wF1=0.6833 hap_exc=0.599 ang_fru=0.662
#   ep26/30 3.2s  tr_loss=0.4016 val_wF1=0.7162  test_wF1=0.6867 hap_exc=0.617 ang_fru=0.658
#   ep27/30 3.2s  tr_loss=0.4160 val_wF1=0.7214  test_wF1=0.6854 hap_exc=0.612 ang_fru=0.655
#   ep28/30 3.2s  tr_loss=0.4123 val_wF1=0.7184  test_wF1=0.6864 hap_exc=0.615 ang_fru=0.659
#   ep29/30 3.2s  tr_loss=0.4018 val_wF1=0.7200  test_wF1=0.6866 hap_exc=0.613 ang_fru=0.660
#   ep30/30 3.2s  tr_loss=0.4063 val_wF1=0.7200  test_wF1=0.6860 hap_exc=0.613 ang_fru=0.658
#   BEST-VAL ep18: acc=0.6741 wF1=0.6750 mF1=0.6632
#
# Phase 2 (contrastive design):
#   L4_cbfc_g0         wF1=0.6794  mF1=0.6686  hap_exc=0.6190  ang_fru=0.6576
#   L4_cbfc_g1         wF1=0.6848  mF1=0.6747  hap_exc=0.6284  ang_fru=0.6664
#   L4_cbfc_g2         wF1=0.6804  mF1=0.6670  hap_exc=0.6076  ang_fru=0.6652
#   L5_bcl_dia         wF1=0.6770  mF1=0.6654  hap_exc=0.6010  ang_fru=0.6644
#   L5_bcl_global      wF1=0.6880  mF1=0.6779  hap_exc=0.6167  ang_fru=0.6701
#   L5_contrast_off    wF1=0.6750  mF1=0.6632  hap_exc=0.6022  ang_fru=0.6398
#
# => contrastive winner: L5_bcl_global

# %% [markdown]
# ## Phase 3 — EACL anchors (+ interaction with contrastive)

# %%
# ── Phase 3: EACL on top of the contrastive winner, plus the interaction cell
# (EACL with contrastive off) — if the pair-F1 gain only appears without the
# contrastive term, the two losses are redundant and the cheaper one stays.
all_results = _load_results()
phase3 = {
    'L6_eacl':            replace(CONTRAST_AB, eacl=True),
    'L6b_eacl_noContrast': replace(BASE_AB, contrastive='off', eacl=True),
}
for name, ab in phase3.items():
    if name in all_results:
        print(f'[SKIP] {name}')
        continue
    run_ablation(name, ab)

res = _load_results()
print('\nEACL verdict — judged on pair F1, not wF1:')
for k in [CONTRAST_NAME] + list(phase3):
    r = res[k]
    print(f"  {k:22s} wF1={r['test_wf1']:.4f}  "
          f"hap_exc={r['pair_hap_exc']:.4f}  ang_fru={r['pair_ang_fru']:.4f}")
print('\nCheck anchor_cos_hap_exc in the history files: it must DECREASE over '
      'epochs for the loss to be doing its job.')
# Out:
# ============================================================
#   RUN: L6_eacl  (epochs=30, seed=42)
# ============================================================
#   #params: 3.87M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='bcl_global', cbfc_gamma=2.0, contrast_mu=0.1, eacl=True, eacl_lambda=0.2)
# /mnt/Work/Environments/Ubuntu/Conda/envs/hopeful/lib/python3.10/site-packages/torch/_compile.py:54: UserWarning: optimizer contains a parameter group with duplicate parameters; in future, this will cause an error; see github.com/pytorch/pytorch/issues/40967 for more information
#   return disable_fn(*args, **kwargs)
#   ep01/30 3.5s  tr_loss=2.1818 val_wF1=0.3788  test_wF1=0.3141 hap_exc=0.244 ang_fru=0.307  [BEST-VAL]
#   ep02/30 3.3s  tr_loss=1.7659 val_wF1=0.4897  test_wF1=0.4802 hap_exc=0.420 ang_fru=0.421  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.5437 val_wF1=0.5990  test_wF1=0.6106 hap_exc=0.514 ang_fru=0.576  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.3672 val_wF1=0.6092  test_wF1=0.5973 hap_exc=0.447 ang_fru=0.606  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.2596 val_wF1=0.6145  test_wF1=0.6234 hap_exc=0.501 ang_fru=0.584  [BEST-VAL]
#   ep06/30 3.3s  tr_loss=1.1838 val_wF1=0.6790  test_wF1=0.6600 hap_exc=0.563 ang_fru=0.627  [BEST-VAL]
#   ep07/30 3.3s  tr_loss=1.0997 val_wF1=0.6727  test_wF1=0.6528 hap_exc=0.570 ang_fru=0.616
#   ep08/30 3.3s  tr_loss=1.0495 val_wF1=0.6863  test_wF1=0.6138 hap_exc=0.487 ang_fru=0.640  [BEST-VAL]
#   ep09/30 3.3s  tr_loss=1.0037 val_wF1=0.6228  test_wF1=0.6455 hap_exc=0.576 ang_fru=0.606
#   ep10/30 3.3s  tr_loss=1.0098 val_wF1=0.7018  test_wF1=0.6585 hap_exc=0.586 ang_fru=0.632  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=0.9407 val_wF1=0.6135  test_wF1=0.5832 hap_exc=0.455 ang_fru=0.641
#   ep12/30 3.3s  tr_loss=0.9264 val_wF1=0.7109  test_wF1=0.6431 hap_exc=0.553 ang_fru=0.611  [BEST-VAL]
#   ep13/30 3.3s  tr_loss=0.8725 val_wF1=0.6938  test_wF1=0.6440 hap_exc=0.545 ang_fru=0.647
#   ep14/30 3.3s  tr_loss=0.8215 val_wF1=0.7046  test_wF1=0.6450 hap_exc=0.547 ang_fru=0.635
#   ep15/30 3.3s  tr_loss=0.7922 val_wF1=0.7120  test_wF1=0.6523 hap_exc=0.562 ang_fru=0.633  [BEST-VAL]
#   ep16/30 3.3s  tr_loss=0.7723 val_wF1=0.6946  test_wF1=0.6555 hap_exc=0.571 ang_fru=0.641
#   ep17/30 3.3s  tr_loss=0.7465 val_wF1=0.7011  test_wF1=0.6488 hap_exc=0.561 ang_fru=0.640
#   ep18/30 3.3s  tr_loss=0.7383 val_wF1=0.7184  test_wF1=0.6634 hap_exc=0.554 ang_fru=0.658  [BEST-VAL]
#   ep19/30 3.3s  tr_loss=0.7125 val_wF1=0.7210  test_wF1=0.6565 hap_exc=0.570 ang_fru=0.639  [BEST-VAL]
#   ep20/30 3.3s  tr_loss=0.6928 val_wF1=0.7082  test_wF1=0.6614 hap_exc=0.580 ang_fru=0.651
#   ep21/30 3.3s  tr_loss=0.6598 val_wF1=0.7091  test_wF1=0.6693 hap_exc=0.591 ang_fru=0.648
#   ep22/30 3.3s  tr_loss=0.6529 val_wF1=0.7157  test_wF1=0.6586 hap_exc=0.565 ang_fru=0.642
#   ep23/30 3.3s  tr_loss=0.6441 val_wF1=0.7095  test_wF1=0.6566 hap_exc=0.567 ang_fru=0.642
#   ep24/30 3.3s  tr_loss=0.6328 val_wF1=0.7116  test_wF1=0.6622 hap_exc=0.582 ang_fru=0.650
#   ep25/30 3.3s  tr_loss=0.6175 val_wF1=0.7110  test_wF1=0.6606 hap_exc=0.570 ang_fru=0.646
#   ep26/30 3.3s  tr_loss=0.6167 val_wF1=0.7142  test_wF1=0.6617 hap_exc=0.578 ang_fru=0.647
#   ep27/30 3.3s  tr_loss=0.6148 val_wF1=0.7184  test_wF1=0.6608 hap_exc=0.574 ang_fru=0.648
#   ep28/30 3.3s  tr_loss=0.6117 val_wF1=0.7148  test_wF1=0.6588 hap_exc=0.574 ang_fru=0.642
#   ep29/30 3.3s  tr_loss=0.6117 val_wF1=0.7148  test_wF1=0.6582 hap_exc=0.575 ang_fru=0.642
#   ep30/30 3.3s  tr_loss=0.6099 val_wF1=0.7130  test_wF1=0.6582 hap_exc=0.575 ang_fru=0.642
#   BEST-VAL ep19: acc=0.6513 wF1=0.6565 mF1=0.6454
#
# ============================================================
#   RUN: L6b_eacl_noContrast  (epochs=30, seed=42)
# ============================================================
#   #params: 3.87M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='off', cbfc_gamma=2.0, contrast_mu=0.1, eacl=True, eacl_lambda=0.2)
# /mnt/Work/Environments/Ubuntu/Conda/envs/hopeful/lib/python3.10/site-packages/torch/_compile.py:54: UserWarning: optimizer contains a parameter group with duplicate parameters; in future, this will cause an error; see github.com/pytorch/pytorch/issues/40967 for more information
#   return disable_fn(*args, **kwargs)
#   ep01/30 3.4s  tr_loss=2.0176 val_wF1=0.3278  test_wF1=0.3020 hap_exc=0.241 ang_fru=0.244  [BEST-VAL]
#   ep02/30 3.3s  tr_loss=1.6450 val_wF1=0.4894  test_wF1=0.4578 hap_exc=0.351 ang_fru=0.466  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.3862 val_wF1=0.5872  test_wF1=0.6095 hap_exc=0.517 ang_fru=0.572  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.2286 val_wF1=0.6107  test_wF1=0.6241 hap_exc=0.551 ang_fru=0.594  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.1071 val_wF1=0.6097  test_wF1=0.6410 hap_exc=0.539 ang_fru=0.603
#   ep06/30 3.3s  tr_loss=1.0253 val_wF1=0.6703  test_wF1=0.6581 hap_exc=0.562 ang_fru=0.634  [BEST-VAL]
#   ep07/30 3.4s  tr_loss=0.9554 val_wF1=0.6705  test_wF1=0.6514 hap_exc=0.542 ang_fru=0.646  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=0.9236 val_wF1=0.6916  test_wF1=0.6179 hap_exc=0.485 ang_fru=0.621  [BEST-VAL]
#   ep09/30 3.3s  tr_loss=0.8626 val_wF1=0.6478  test_wF1=0.6508 hap_exc=0.554 ang_fru=0.618
#   ep10/30 3.3s  tr_loss=0.8394 val_wF1=0.6996  test_wF1=0.6357 hap_exc=0.562 ang_fru=0.605  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=0.8237 val_wF1=0.6244  test_wF1=0.6335 hap_exc=0.511 ang_fru=0.657
#   ep12/30 3.3s  tr_loss=0.7922 val_wF1=0.7192  test_wF1=0.6645 hap_exc=0.571 ang_fru=0.644  [BEST-VAL]
#   ep13/30 3.3s  tr_loss=0.7385 val_wF1=0.7186  test_wF1=0.6819 hap_exc=0.586 ang_fru=0.665
#   ep14/30 3.3s  tr_loss=0.7044 val_wF1=0.6980  test_wF1=0.6463 hap_exc=0.529 ang_fru=0.641
#   ep15/30 3.3s  tr_loss=0.6710 val_wF1=0.6994  test_wF1=0.6628 hap_exc=0.563 ang_fru=0.648
#   ep16/30 3.3s  tr_loss=0.6407 val_wF1=0.6883  test_wF1=0.6698 hap_exc=0.576 ang_fru=0.651
#   ep17/30 3.3s  tr_loss=0.6345 val_wF1=0.7062  test_wF1=0.6627 hap_exc=0.573 ang_fru=0.654
#   ep18/30 3.3s  tr_loss=0.6083 val_wF1=0.7022  test_wF1=0.6768 hap_exc=0.588 ang_fru=0.652
#   ep19/30 3.3s  tr_loss=0.5960 val_wF1=0.7107  test_wF1=0.6525 hap_exc=0.553 ang_fru=0.639
#   ep20/30 3.3s  tr_loss=0.5833 val_wF1=0.7012  test_wF1=0.6716 hap_exc=0.584 ang_fru=0.654
#   ep21/30 3.3s  tr_loss=0.5598 val_wF1=0.6964  test_wF1=0.6605 hap_exc=0.579 ang_fru=0.638
#   ep22/30 3.3s  tr_loss=0.5564 val_wF1=0.7180  test_wF1=0.6804 hap_exc=0.598 ang_fru=0.658
#   ep23/30 3.3s  tr_loss=0.5434 val_wF1=0.6982  test_wF1=0.6606 hap_exc=0.585 ang_fru=0.630
#   ep24/30 3.3s  tr_loss=0.5254 val_wF1=0.7226  test_wF1=0.6712 hap_exc=0.574 ang_fru=0.658  [BEST-VAL]
#   ep25/30 3.3s  tr_loss=0.5232 val_wF1=0.6999  test_wF1=0.6801 hap_exc=0.601 ang_fru=0.657
#   ep26/30 3.3s  tr_loss=0.5150 val_wF1=0.7065  test_wF1=0.6783 hap_exc=0.599 ang_fru=0.653
#   ep27/30 3.3s  tr_loss=0.5000 val_wF1=0.7099  test_wF1=0.6786 hap_exc=0.599 ang_fru=0.654
#   ep28/30 3.3s  tr_loss=0.5049 val_wF1=0.7084  test_wF1=0.6762 hap_exc=0.595 ang_fru=0.651
#   ep29/30 3.3s  tr_loss=0.5008 val_wF1=0.7085  test_wF1=0.6755 hap_exc=0.595 ang_fru=0.651
#   ep30/30 3.3s  tr_loss=0.5052 val_wF1=0.7085  test_wF1=0.6767 hap_exc=0.595 ang_fru=0.654
#   BEST-VAL ep24: acc=0.6642 wF1=0.6712 mF1=0.6576
#
# EACL verdict — judged on pair F1, not wF1:
#   L5_bcl_global          wF1=0.6880  hap_exc=0.6167  ang_fru=0.6701
#   L6_eacl                wF1=0.6565  hap_exc=0.5702  ang_fru=0.6395
#   L6b_eacl_noContrast    wF1=0.6712  hap_exc=0.5741  ang_fru=0.6578
#
# Check anchor_cos_hap_exc in the history files: it must DECREASE over epochs for the loss to be doing its job.

# %% [markdown]
# ## Phase 4 — winner stack, 3 seeds

# %%
# ── Phase 4: confirm the winner stack at 3 seeds
res = _load_results()
singles = {k: res[k]['test_wf1'] for k in res
           if k.startswith('L') and '_s4' not in k}
WINNER_NAME = max(singles, key=singles.get)
print(f'Winner by wF1: {WINNER_NAME}  ({singles[WINNER_NAME]:.4f})')
print('(Override WINNER_AB manually if the pair-F1 picture argues otherwise.)')

_ab_lookup = {**L_GRID_3A, **phase2, **phase3}
WINNER_AB = _ab_lookup[WINNER_NAME]
run_sweep('L7_winner', WINNER_AB)
# Out:
# Winner by wF1: L5_bcl_global  (0.6880)
# (Override WINNER_AB manually if the pair-F1 picture argues otherwise.)
#
# ============================================================
#   RUN: L7_winner_s42  (epochs=30, seed=42)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='bcl_global', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=1.8796 val_wF1=0.4200  test_wF1=0.3450 hap_exc=0.282 ang_fru=0.371  [BEST-VAL]
#   ep02/30 3.4s  tr_loss=1.5098 val_wF1=0.4818  test_wF1=0.4807 hap_exc=0.448 ang_fru=0.504  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.2629 val_wF1=0.4783  test_wF1=0.5435 hap_exc=0.491 ang_fru=0.440
#   ep04/30 3.2s  tr_loss=1.1594 val_wF1=0.6282  test_wF1=0.6278 hap_exc=0.545 ang_fru=0.583  [BEST-VAL]
#   ep05/30 3.2s  tr_loss=1.0569 val_wF1=0.6754  test_wF1=0.6443 hap_exc=0.545 ang_fru=0.613  [BEST-VAL]
#   ep06/30 3.2s  tr_loss=1.0181 val_wF1=0.6232  test_wF1=0.6065 hap_exc=0.455 ang_fru=0.601
#   ep07/30 3.2s  tr_loss=0.9339 val_wF1=0.6661  test_wF1=0.6471 hap_exc=0.531 ang_fru=0.633
#   ep08/30 3.2s  tr_loss=0.8836 val_wF1=0.6986  test_wF1=0.6678 hap_exc=0.593 ang_fru=0.628  [BEST-VAL]
#   ep09/30 3.2s  tr_loss=0.8612 val_wF1=0.6444  test_wF1=0.6272 hap_exc=0.549 ang_fru=0.589
#   ep10/30 3.2s  tr_loss=0.8160 val_wF1=0.6813  test_wF1=0.6671 hap_exc=0.607 ang_fru=0.654
#   ep11/30 3.2s  tr_loss=0.8157 val_wF1=0.7014  test_wF1=0.6630 hap_exc=0.593 ang_fru=0.638  [BEST-VAL]
#   ep12/30 3.2s  tr_loss=0.7497 val_wF1=0.6837  test_wF1=0.6695 hap_exc=0.599 ang_fru=0.639
#   ep13/30 3.3s  tr_loss=0.7186 val_wF1=0.6707  test_wF1=0.6474 hap_exc=0.549 ang_fru=0.640
#   ep14/30 3.2s  tr_loss=0.6853 val_wF1=0.7106  test_wF1=0.6893 hap_exc=0.624 ang_fru=0.664  [BEST-VAL]
#   ep15/30 3.2s  tr_loss=0.6842 val_wF1=0.6946  test_wF1=0.6532 hap_exc=0.546 ang_fru=0.655
#   ep16/30 3.2s  tr_loss=0.6642 val_wF1=0.7240  test_wF1=0.6897 hap_exc=0.617 ang_fru=0.654  [BEST-VAL]
#   ep17/30 3.2s  tr_loss=0.6387 val_wF1=0.7149  test_wF1=0.6777 hap_exc=0.625 ang_fru=0.639
#   ep18/30 3.2s  tr_loss=0.6121 val_wF1=0.7281  test_wF1=0.6826 hap_exc=0.604 ang_fru=0.658  [BEST-VAL]
#   ep19/30 3.2s  tr_loss=0.5927 val_wF1=0.7231  test_wF1=0.6839 hap_exc=0.600 ang_fru=0.670
#   ep20/30 3.2s  tr_loss=0.5841 val_wF1=0.7291  test_wF1=0.6951 hap_exc=0.629 ang_fru=0.678  [BEST-VAL]
#   ep21/30 3.2s  tr_loss=0.5628 val_wF1=0.7222  test_wF1=0.6757 hap_exc=0.594 ang_fru=0.653
#   ep22/30 3.2s  tr_loss=0.5586 val_wF1=0.7349  test_wF1=0.6980 hap_exc=0.635 ang_fru=0.678  [BEST-VAL]
#   ep23/30 3.3s  tr_loss=0.5498 val_wF1=0.7371  test_wF1=0.6904 hap_exc=0.620 ang_fru=0.671  [BEST-VAL]
#   ep24/30 3.2s  tr_loss=0.5355 val_wF1=0.7283  test_wF1=0.6872 hap_exc=0.618 ang_fru=0.663
#   ep25/30 3.2s  tr_loss=0.5218 val_wF1=0.7365  test_wF1=0.6899 hap_exc=0.616 ang_fru=0.668
#   ep26/30 3.2s  tr_loss=0.5173 val_wF1=0.7353  test_wF1=0.6945 hap_exc=0.623 ang_fru=0.674
#   ep27/30 3.3s  tr_loss=0.5136 val_wF1=0.7310  test_wF1=0.6909 hap_exc=0.619 ang_fru=0.665
#   ep28/30 3.3s  tr_loss=0.5199 val_wF1=0.7380  test_wF1=0.6922 hap_exc=0.622 ang_fru=0.667  [BEST-VAL]
#   ep29/30 3.3s  tr_loss=0.5043 val_wF1=0.7324  test_wF1=0.6922 hap_exc=0.622 ang_fru=0.668
#   ep30/30 3.3s  tr_loss=0.5187 val_wF1=0.7324  test_wF1=0.6922 hap_exc=0.622 ang_fru=0.668
#   BEST-VAL ep28: acc=0.6876 wF1=0.6922 mF1=0.6816
#
# ============================================================
#   RUN: L7_winner_s43  (epochs=30, seed=43)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='bcl_global', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.3s  tr_loss=1.8831 val_wF1=0.4482  test_wF1=0.3942 hap_exc=0.309 ang_fru=0.362  [BEST-VAL]
#   ep02/30 3.3s  tr_loss=1.4436 val_wF1=0.5497  test_wF1=0.4906 hap_exc=0.513 ang_fru=0.541  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.2450 val_wF1=0.5417  test_wF1=0.6073 hap_exc=0.471 ang_fru=0.561
#   ep04/30 3.3s  tr_loss=1.1679 val_wF1=0.5662  test_wF1=0.5792 hap_exc=0.527 ang_fru=0.534  [BEST-VAL]
#   ep05/30 3.3s  tr_loss=1.0953 val_wF1=0.5593  test_wF1=0.6001 hap_exc=0.530 ang_fru=0.504
#   ep06/30 3.3s  tr_loss=1.0098 val_wF1=0.6722  test_wF1=0.6540 hap_exc=0.550 ang_fru=0.622  [BEST-VAL]
#   ep07/30 3.3s  tr_loss=0.9427 val_wF1=0.6246  test_wF1=0.6400 hap_exc=0.525 ang_fru=0.623
#   ep08/30 3.3s  tr_loss=0.9356 val_wF1=0.6547  test_wF1=0.6338 hap_exc=0.546 ang_fru=0.585
#   ep09/30 3.3s  tr_loss=0.8590 val_wF1=0.6197  test_wF1=0.6514 hap_exc=0.568 ang_fru=0.613
#   ep10/30 3.3s  tr_loss=0.8129 val_wF1=0.6837  test_wF1=0.6859 hap_exc=0.566 ang_fru=0.650  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=0.7784 val_wF1=0.7007  test_wF1=0.6770 hap_exc=0.585 ang_fru=0.659  [BEST-VAL]
#   ep12/30 3.3s  tr_loss=0.7508 val_wF1=0.6750  test_wF1=0.6644 hap_exc=0.563 ang_fru=0.638
#   ep13/30 3.3s  tr_loss=0.7236 val_wF1=0.6881  test_wF1=0.6648 hap_exc=0.589 ang_fru=0.618
#   ep14/30 3.3s  tr_loss=0.7184 val_wF1=0.7080  test_wF1=0.6691 hap_exc=0.550 ang_fru=0.659  [BEST-VAL]
#   ep15/30 3.3s  tr_loss=0.6775 val_wF1=0.7140  test_wF1=0.6843 hap_exc=0.602 ang_fru=0.652  [BEST-VAL]
#   ep16/30 3.3s  tr_loss=0.6731 val_wF1=0.7046  test_wF1=0.6876 hap_exc=0.596 ang_fru=0.664
#   ep17/30 3.3s  tr_loss=0.6471 val_wF1=0.7090  test_wF1=0.6713 hap_exc=0.584 ang_fru=0.642
#   ep18/30 3.3s  tr_loss=0.6144 val_wF1=0.6953  test_wF1=0.6803 hap_exc=0.601 ang_fru=0.651
#   ep19/30 3.3s  tr_loss=0.6031 val_wF1=0.7260  test_wF1=0.6851 hap_exc=0.598 ang_fru=0.671  [BEST-VAL]
#   ep20/30 3.4s  tr_loss=0.5829 val_wF1=0.7214  test_wF1=0.6952 hap_exc=0.624 ang_fru=0.665
#   ep21/30 3.3s  tr_loss=0.5579 val_wF1=0.7065  test_wF1=0.6805 hap_exc=0.585 ang_fru=0.665
#   ep22/30 3.3s  tr_loss=0.5493 val_wF1=0.7184  test_wF1=0.6872 hap_exc=0.602 ang_fru=0.665
#   ep23/30 3.3s  tr_loss=0.5378 val_wF1=0.7275  test_wF1=0.6836 hap_exc=0.617 ang_fru=0.653  [BEST-VAL]
#   ep24/30 3.3s  tr_loss=0.5353 val_wF1=0.7248  test_wF1=0.6918 hap_exc=0.624 ang_fru=0.667
#   ep25/30 3.3s  tr_loss=0.5183 val_wF1=0.7227  test_wF1=0.6934 hap_exc=0.624 ang_fru=0.668
#   ep26/30 3.3s  tr_loss=0.5083 val_wF1=0.7067  test_wF1=0.6841 hap_exc=0.616 ang_fru=0.652
#   ep27/30 3.3s  tr_loss=0.5012 val_wF1=0.7100  test_wF1=0.6885 hap_exc=0.612 ang_fru=0.665
#   ep28/30 3.3s  tr_loss=0.5135 val_wF1=0.7083  test_wF1=0.6904 hap_exc=0.618 ang_fru=0.666
#   ep29/30 3.3s  tr_loss=0.5140 val_wF1=0.7121  test_wF1=0.6873 hap_exc=0.617 ang_fru=0.660
#   ep30/30 3.4s  tr_loss=0.5038 val_wF1=0.7121  test_wF1=0.6859 hap_exc=0.618 ang_fru=0.656
#   BEST-VAL ep23: acc=0.6839 wF1=0.6836 mF1=0.6711
#
# ============================================================
#   RUN: L7_winner_s44  (epochs=30, seed=44)
# ============================================================
#   #params: 3.86M   ab=AblationCfg(label_smoothing=0.0, cb_weights=True, contrastive='bcl_global', cbfc_gamma=2.0, contrast_mu=0.1, eacl=False, eacl_lambda=0.2)
#   ep01/30 3.4s  tr_loss=1.8377 val_wF1=0.3180  test_wF1=0.2589 hap_exc=0.301 ang_fru=0.214  [BEST-VAL]
#   ep02/30 3.3s  tr_loss=1.4902 val_wF1=0.4632  test_wF1=0.4418 hap_exc=0.363 ang_fru=0.506  [BEST-VAL]
#   ep03/30 3.3s  tr_loss=1.3234 val_wF1=0.6357  test_wF1=0.5729 hap_exc=0.495 ang_fru=0.597  [BEST-VAL]
#   ep04/30 3.3s  tr_loss=1.1634 val_wF1=0.6350  test_wF1=0.6221 hap_exc=0.528 ang_fru=0.621
#   ep05/30 3.3s  tr_loss=1.0701 val_wF1=0.6260  test_wF1=0.6343 hap_exc=0.548 ang_fru=0.612
#   ep06/30 3.3s  tr_loss=1.0369 val_wF1=0.6359  test_wF1=0.6509 hap_exc=0.533 ang_fru=0.628  [BEST-VAL]
#   ep07/30 3.3s  tr_loss=0.9751 val_wF1=0.6911  test_wF1=0.6306 hap_exc=0.506 ang_fru=0.626  [BEST-VAL]
#   ep08/30 3.3s  tr_loss=0.9229 val_wF1=0.6423  test_wF1=0.6519 hap_exc=0.559 ang_fru=0.624
#   ep09/30 3.4s  tr_loss=0.8560 val_wF1=0.6361  test_wF1=0.6320 hap_exc=0.536 ang_fru=0.610
#   ep10/30 3.3s  tr_loss=0.8272 val_wF1=0.6936  test_wF1=0.6535 hap_exc=0.558 ang_fru=0.621  [BEST-VAL]
#   ep11/30 3.3s  tr_loss=0.7876 val_wF1=0.6463  test_wF1=0.6444 hap_exc=0.537 ang_fru=0.631
#   ep12/30 3.3s  tr_loss=0.7423 val_wF1=0.7161  test_wF1=0.6681 hap_exc=0.564 ang_fru=0.649  [BEST-VAL]
#   ep13/30 3.3s  tr_loss=0.7265 val_wF1=0.7076  test_wF1=0.6798 hap_exc=0.587 ang_fru=0.656
#   ep14/30 3.3s  tr_loss=0.6769 val_wF1=0.6971  test_wF1=0.6744 hap_exc=0.580 ang_fru=0.663
#   ep15/30 3.3s  tr_loss=0.6683 val_wF1=0.7322  test_wF1=0.6726 hap_exc=0.605 ang_fru=0.641  [BEST-VAL]
#   ep16/30 3.2s  tr_loss=0.6350 val_wF1=0.7423  test_wF1=0.6766 hap_exc=0.589 ang_fru=0.654  [BEST-VAL]
#   ep17/30 3.3s  tr_loss=0.6189 val_wF1=0.7200  test_wF1=0.6736 hap_exc=0.566 ang_fru=0.672
#   ep18/30 3.3s  tr_loss=0.6126 val_wF1=0.7521  test_wF1=0.6734 hap_exc=0.599 ang_fru=0.651  [BEST-VAL]
#   ep19/30 3.3s  tr_loss=0.5954 val_wF1=0.7290  test_wF1=0.6798 hap_exc=0.602 ang_fru=0.656
#   ep20/30 3.3s  tr_loss=0.5735 val_wF1=0.7391  test_wF1=0.6870 hap_exc=0.611 ang_fru=0.677
#   ep21/30 3.3s  tr_loss=0.5615 val_wF1=0.7243  test_wF1=0.6677 hap_exc=0.585 ang_fru=0.631
#   ep22/30 3.3s  tr_loss=0.5532 val_wF1=0.7361  test_wF1=0.6903 hap_exc=0.608 ang_fru=0.676
#   ep23/30 3.3s  tr_loss=0.5341 val_wF1=0.7265  test_wF1=0.6826 hap_exc=0.602 ang_fru=0.659
#   ep24/30 3.3s  tr_loss=0.5220 val_wF1=0.7238  test_wF1=0.6916 hap_exc=0.617 ang_fru=0.665
#   ep25/30 3.3s  tr_loss=0.5173 val_wF1=0.7286  test_wF1=0.6831 hap_exc=0.595 ang_fru=0.665
#   ep26/30 3.3s  tr_loss=0.5181 val_wF1=0.7378  test_wF1=0.6801 hap_exc=0.603 ang_fru=0.651
#   ep27/30 3.4s  tr_loss=0.5068 val_wF1=0.7305  test_wF1=0.6821 hap_exc=0.599 ang_fru=0.666
#   ep28/30 3.3s  tr_loss=0.5056 val_wF1=0.7306  test_wF1=0.6843 hap_exc=0.603 ang_fru=0.669
#   ep29/30 3.3s  tr_loss=0.5118 val_wF1=0.7291  test_wF1=0.6854 hap_exc=0.603 ang_fru=0.668
#   ep30/30 3.3s  tr_loss=0.5005 val_wF1=0.7307  test_wF1=0.6854 hap_exc=0.603 ang_fru=0.668
#   BEST-VAL ep18: acc=0.6710 wF1=0.6734 mF1=0.6606
#
# L7_winner: wF1 0.6831±0.0077  mF1 0.6711±0.0086  acc 0.6808±0.0071
# {'test_acc': (0.680837954405422, 0.007132370242014914),
#  'test_wf1': (0.6830848094404014, 0.007682956652916044),
#  'test_mf1': (0.6710776497026055, 0.008575431625099009)}

# %% [markdown]
# ## Results Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

res = _load_results()
rows = []
for name, r in sorted(res.items()):
    rows.append({'Variant': name, 'Acc': r['test_acc'], 'wF1': r['test_wf1'],
                 'mF1': r['test_mf1'], 'BestEpoch': r.get('best_val_epoch', -1),
                 **{k: v for k, v in r.items() if k.startswith('pair_')}})
df = pd.DataFrame(rows).set_index('Variant')

REFERENCE = 'L3_ls01_cbOn'
if REFERENCE in df.index:
    for c in ('Acc', 'wF1', 'mF1'):
        df[f'D_{c}'] = df[c] - df.loc[REFERENCE, c]

print(f'=== M3 Loss Design — results (reference: {REFERENCE}) ===')
print(df.to_string(float_format='{:.4f}'.format))
df.to_csv(ABL_OUT / 'summary_table.csv')

ax = df[['Acc', 'wF1', 'mF1']].plot.bar(figsize=(max(10, len(df)), 5))
if REFERENCE in df.index:
    ax.axhline(df.loc[REFERENCE, 'wF1'], ls='--', c='gray', lw=1)
plt.title('M3 Loss Design — test metrics'); plt.ylabel('score'); plt.tight_layout()
plt.savefig(PLOT_DIR / 'metrics_bar.png', dpi=150); plt.show()
# Out:
# === M3 Loss Design — results (reference: L3_ls01_cbOn) ===
#                        Acc    wF1    mF1  BestEpoch  pair_hap_exc  pair_ang_fru   D_Acc   D_wF1   D_mF1
# Variant
# L0_ls00_cbOff       0.6895 0.6836 0.6599         16        0.5729        0.6594  0.0123  0.0069  0.0016
# L1_ls00_cbOn        0.6827 0.6829 0.6682         16        0.6065        0.6579  0.0055  0.0062  0.0099
# L2_ls01_cbOff       0.6778 0.6764 0.6590         17        0.5813        0.6393  0.0006 -0.0003  0.0007
# L3_ls01_cbOn        0.6771 0.6767 0.6583         14        0.5915        0.6527  0.0000  0.0000  0.0000
# L4_cbfc_g0          0.6759 0.6794 0.6686         19        0.6190        0.6576 -0.0012  0.0027  0.0103
# L4_cbfc_g1          0.6821 0.6848 0.6747         22        0.6284        0.6664  0.0049  0.0082  0.0164
# L4_cbfc_g2          0.6759 0.6804 0.6670         20        0.6076        0.6652 -0.0012  0.0038  0.0087
# L5_bcl_dia          0.6722 0.6770 0.6654         25        0.6010        0.6644 -0.0049  0.0003  0.0071
# L5_bcl_global       0.6833 0.6880 0.6779         27        0.6167        0.6701  0.0062  0.0113  0.0196
# L5_contrast_off     0.6741 0.6750 0.6632         18        0.6022        0.6398 -0.0031 -0.0017  0.0049
# L6_eacl             0.6513 0.6565 0.6454         19        0.5702        0.6395 -0.0259 -0.0202 -0.0129
# L6b_eacl_noContrast 0.6642 0.6712 0.6576         24        0.5741        0.6578 -0.0129 -0.0055 -0.0007
# L7_winner_s42       0.6876 0.6922 0.6816         28        0.6223        0.6668  0.0105  0.0156  0.0233
# L7_winner_s43       0.6839 0.6836 0.6711         23        0.6171        0.6529  0.0068  0.0069  0.0128
# L7_winner_s44       0.6710 0.6734 0.6606         18        0.5988        0.6507 -0.0062 -0.0032  0.0023

# %%
heat = {}
for name, r in res.items():
    yt = np.array(r.get('y_true', [])); yp = np.array(r.get('y_pred', []))
    if len(yt) == 0:
        continue
    heat[name] = f1_score(yt, yp, average=None, labels=list(range(N_CLS)))
if heat:
    hdf = pd.DataFrame(heat, index=EMO).T.sort_index()
    plt.figure(figsize=(10, 0.5 * len(hdf) + 2))
    sns.heatmap(hdf, annot=True, fmt='.3f', cmap='RdYlGn',
                cbar_kws={'label': 'F1'})
    plt.title('M3 Loss Design — per-emotion F1'); plt.tight_layout()
    plt.savefig(PLOT_DIR / 'per_emotion_heatmap.png', dpi=150); plt.show()

# %%
# McNemar significance of every variant vs the reference
res = _load_results()
ref = 'L3_ls01_cbOn'
if ref in res:
    print(f'McNemar p-values vs {ref}:')
    for name in sorted(res):
        if name == ref or not res[name].get('y_pred'):
            continue
        try:
            p = mcnemar_vs(ref, name)
            sig = ' *' if p < 0.05 else ''
            print(f'  {name:35s} p={p:.4f}{sig}')
        except Exception as e:
            print(f'  {name:35s} failed: {e}')
# Out:
# McNemar p-values vs L3_ls01_cbOn:
#   L0_ls00_cbOff                       p=0.1769
#   L1_ls00_cbOn                        p=0.5667
#   L2_ls01_cbOff                       p=1.0000
#   L4_cbfc_g0                          p=0.9358
#   L4_cbfc_g1                          p=0.5823
#   L4_cbfc_g2                          p=0.9396
#   L5_bcl_dia                          p=0.6258
#   L5_bcl_global                       p=0.5365
#   L5_contrast_off                     p=0.7569
#   L6_eacl                             p=0.0098 *
#   L6b_eacl_noContrast                 p=0.1995
#   L7_winner_s42                       p=0.2707
#   L7_winner_s43                       p=0.5328
#   L7_winner_s44                       p=0.5266
